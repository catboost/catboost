# %% [markdown]
# # Comparing algorithms on the Click dataset
# The data is taken from [this source](http://www.kdd.org/kdd-cup/view/kdd-cup-2012-track-2).

# %% [markdown]
# For details on running the comparison, see [this article](https://github.com/catboost/benchmarks/blob/master/comparison_description.pdf).

# %%
from experiment import Experiment
from xgboost_experiment import XGBExperiment
from lightgbm_experiment import LGBExperiment
from catboost_experiment import CABExperiment

# %% [markdown]
# Load the dataset and set parameters for the experiment.

# %%
learning_task = 'classification'
dataset_path = '/media/pool_storage/tsnet-pools-converted/click/'
n_estimators = 5000
max_hyperopt_evals = 50

experiment = Experiment(learning_task, train_path=dataset_path + 'train_full3',
                        test_path=dataset_path + 'test3', cd_path = dataset_path + 'train_full3.cd')
X_train, y_train, X_test, y_test, cat_cols = experiment.read_data()

# %% [markdown]
# Write a function that does the following:
#
# **Preprocess the dataset:**
# calculate counter values on the training set, transform cat features (for the `XGBoost` and `LightGBM` algorithms), and convert the data to the format of the algorithm. Do the same thing with all pairs after splitting them into cross validation folds.
#
# **Select the optimal number of trees for the algorithm with the default parameters:** for each fold and each number of trees, get the result of the algorithm trained on the other four folds, average the results for each number of trees, and choose the best one.
#
# **Assess the quality of the algorithm with the default parameters on a test dataset:** train the algorithm with the number of trees obtained in the previous step, and calculate the metric value on the test dataset.
#
# **Tune parameters for the algorithm using `Hyperopt`:** on each `Hyperopt` iteration of the algorithm, the best value of trees is selected and the metric for cross validation is calculated.
#
# **Show results on the test dataset for the algorithm with the tuned parameters:** train the algorithm with the optimal parameters and the number of trees obtained in the previous step, and calculate the metric value on the test dataset.

# %%
import numpy as np

def run_experiment(Experiment, title):
    experiment = Experiment(learning_task, max_hyperopt_evals=max_hyperopt_evals,
                            n_estimators=n_estimators)
    cv_pairs, (dtrain, dtest) = experiment.split_and_preprocess(X_train.copy(), y_train, 
                                                                X_test.copy(), y_test, 
                                                                cat_cols, n_splits=5)
 
    default_cv_result = experiment.run_cv(cv_pairs)
    experiment.print_result(default_cv_result, 'Default {} result on cv'.format(title))

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')

    default_test_losses = []
    for seed in range(5):
        test_result = experiment.run_test(dtrain, dtest, X_test, params=default_cv_result['params'],
                                          n_estimators=default_cv_result['best_n_estimators'], seed=seed)
        default_test_losses.append(test_result['loss'])
        print 'For seed=%d Test\'s %s : %.5f' % (seed, experiment.metric, default_test_losses[-1])
    print '\nTest\'s %s mean: %.5f, Test\'s %s std: %.5f' % (experiment.metric, np.mean(default_test_losses),
                                                             experiment.metric, np.std(default_test_losses))

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')
    print('Hyperopt iterations:\n\n')

    tuned_cv_result = experiment.optimize_params(cv_pairs)

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')

    experiment.print_result(tuned_cv_result, 'Tuned {} result on cv'.format(title))

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')

    tuned_test_losses = []
    for seed in range(5):
        test_result = experiment.run_test(dtrain, dtest, X_test, params=tuned_cv_result['params'],
                                          n_estimators=tuned_cv_result['best_n_estimators'], seed=seed)
        tuned_test_losses.append(test_result['loss'])
        print 'For seed=%d Test\'s %s : %.5f' % (seed, experiment.metric, tuned_test_losses[-1])
    print '\nTest\'s %s mean: %.5f, Test\'s %s std: %.5f' % (experiment.metric, np.mean(tuned_test_losses),
                                                             experiment.metric, np.std(tuned_test_losses))

    return np.mean(default_test_losses), np.mean(tuned_test_losses)

# %% [markdown]
# ## `XGBoost`

# %%
xgb_default_test_result, xgb_tuned_test_result = run_experiment(XGBExperiment, "XGBoost")
# Out:
# Default XGBoost result on cv:
#
# logloss = 0.3991998
# best_n_estimators = 49
# params = {'colsample_bytree': 1.0, 'silent': 1, 'eval_metric': 'logloss', 'colsample_bylevel': 1.0, 'min_child_weight': 1, 'subsample': 1.0, 'eta': 0.3, 'objective': 'binary:logistic', 'alpha': 0, 'seed': 0, 'max_depth': 6, 'gamma': 0, 'lambda': 1}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Default XGBoost result on test:
#
# For seed=0 Test's logloss : 0.397638
# For seed=1 Test's logloss : 0.397638
# For seed=2 Test's logloss : 0.397638
# For seed=3 Test's logloss : 0.397638
# For seed=4 Test's logloss : 0.397638
#
# Test's logloss mean: 0.397638, Test's logloss std: 0.000000
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Hyperopt iterations:
#
# [1/50]	eval_time=1266.27 sec	current_logloss=0.397963	min_logloss=0.397963
# [2/50]	eval_time=1867.30 sec	current_logloss=0.397792	min_logloss=0.397792
# [3/50]	eval_time=1814.91 sec	current_logloss=0.400677	min_logloss=0.397792
# [4/50]	eval_time=878.76 sec	current_logloss=0.398203	min_logloss=0.397792
# [5/50]	eval_time=930.71 sec	current_logloss=0.402263	min_logloss=0.397792
# [6/50]	eval_time=992.24 sec	current_logloss=0.399050	min_logloss=0.397792
# [7/50]	eval_time=1217.90 sec	current_logloss=0.406515	min_logloss=0.397792
# [8/50]	eval_time=1620.53 sec	current_logloss=0.397677	min_logloss=0.397677
# [9/50]	eval_time=1248.05 sec	current_logloss=0.398689	min_logloss=0.397677
# [10/50]	eval_time=2561.80 sec	current_logloss=0.398360	min_logloss=0.397677
# [11/50]	eval_time=817.27 sec	current_logloss=0.399070	min_logloss=0.397677
# [12/50]	eval_time=2149.62 sec	current_logloss=0.398779	min_logloss=0.397677
# [13/50]	eval_time=1085.97 sec	current_logloss=0.399582	min_logloss=0.397677
# [14/50]	eval_time=1196.21 sec	current_logloss=0.397918	min_logloss=0.397677
# [15/50]	eval_time=2227.96 sec	current_logloss=0.398371	min_logloss=0.397677
# [16/50]	eval_time=1354.31 sec	current_logloss=0.399291	min_logloss=0.397677
# [17/50]	eval_time=2100.48 sec	current_logloss=0.397732	min_logloss=0.397677
# [18/50]	eval_time=655.14 sec	current_logloss=0.399640	min_logloss=0.397677
# [19/50]	eval_time=616.96 sec	current_logloss=0.398666	min_logloss=0.397677
# [20/50]	eval_time=1831.61 sec	current_logloss=0.399399	min_logloss=0.397677
# [21/50]	eval_time=2387.27 sec	current_logloss=0.397979	min_logloss=0.397677
# [22/50]	eval_time=2211.64 sec	current_logloss=0.397707	min_logloss=0.397677
# [23/50]	eval_time=2589.21 sec	current_logloss=0.397788	min_logloss=0.397677
# [24/50]	eval_time=1634.08 sec	current_logloss=0.398101	min_logloss=0.397677
# [25/50]	eval_time=2281.84 sec	current_logloss=0.399370	min_logloss=0.397677
# [26/50]	eval_time=2234.70 sec	current_logloss=0.397515	min_logloss=0.397515
# [27/50]	eval_time=1719.55 sec	current_logloss=0.400527	min_logloss=0.397515
# [28/50]	eval_time=2040.52 sec	current_logloss=0.398766	min_logloss=0.397515
# [29/50]	eval_time=1558.15 sec	current_logloss=0.397847	min_logloss=0.397515
# [30/50]	eval_time=2353.18 sec	current_logloss=0.397621	min_logloss=0.397515
# [31/50]	eval_time=2178.52 sec	current_logloss=0.401125	min_logloss=0.397515
# [32/50]	eval_time=2334.74 sec	current_logloss=0.397984	min_logloss=0.397515
# [33/50]	eval_time=2821.71 sec	current_logloss=0.397795	min_logloss=0.397515
# [34/50]	eval_time=2317.37 sec	current_logloss=0.399881	min_logloss=0.397515
# [35/50]	eval_time=2022.47 sec	current_logloss=0.398090	min_logloss=0.397515
# [36/50]	eval_time=2249.16 sec	current_logloss=0.398738	min_logloss=0.397515
# [37/50]	eval_time=2048.29 sec	current_logloss=0.397813	min_logloss=0.397515
# [38/50]	eval_time=3070.32 sec	current_logloss=0.397892	min_logloss=0.397515
# [39/50]	eval_time=2302.93 sec	current_logloss=0.397653	min_logloss=0.397515
# [40/50]	eval_time=1749.86 sec	current_logloss=0.397726	min_logloss=0.397515
# [41/50]	eval_time=1438.02 sec	current_logloss=0.399359	min_logloss=0.397515
# [42/50]	eval_time=2455.09 sec	current_logloss=0.397777	min_logloss=0.397515
# [43/50]	eval_time=1746.30 sec	current_logloss=0.397578	min_logloss=0.397515
# [44/50]	eval_time=1419.55 sec	current_logloss=0.398747	min_logloss=0.397515
# [45/50]	eval_time=1996.06 sec	current_logloss=0.397889	min_logloss=0.397515
# [46/50]	eval_time=1335.70 sec	current_logloss=0.400021	min_logloss=0.397515
# [47/50]	eval_time=1094.76 sec	current_logloss=0.397907	min_logloss=0.397515
# [48/50]	eval_time=1748.97 sec	current_logloss=0.397533	min_logloss=0.397515
# [49/50]	eval_time=1537.42 sec	current_logloss=0.397622	min_logloss=0.397515
# [50/50]	eval_time=1888.97 sec	current_logloss=0.397609	min_logloss=0.397515
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned XGBoost result on cv:
#
# logloss = 0.3975154
# best_n_estimators = 4058
# params = {'colsample_bytree': 0.6711940324507633, 'silent': 1, 'eval_metric': 'logloss', 'colsample_bylevel': 0.9786901375377791, 'min_child_weight': 7.932948016606513, 'subsample': 0.6649331929100485, 'eta': 0.0031376981659186425, 'objective': 'binary:logistic', 'alpha': 0, 'seed': 0, 'max_depth': 8, 'gamma': 0.006105162487943566, 'lambda': 8.335939723249088e-06}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned XGBoost result on test:
#
# For seed=0 Test's logloss : 0.396242
# For seed=1 Test's logloss : 0.396279
# For seed=2 Test's logloss : 0.396244
# For seed=3 Test's logloss : 0.396201
# For seed=4 Test's logloss : 0.396242
#
# Test's logloss mean: 0.396242, Test's logloss std: 0.000025

# %% [markdown]
# ## `LightGBM`

# %%
lgb_default_test_result, lgb_tuned_test_result = run_experiment(LGBExperiment, "LightGBM")
# Out:
# Default LightGBM result on cv:
#
# logloss = 0.398740768002
# best_n_estimators = 57
# params = {'feature_fraction_seed': 0, 'num_leaves': 127, 'verbose': -1, 'bagging_seed': 0, 'lambda_l1': 0, 'drop_seed': 0, 'learning_rate': 0.1, 'lambda_l2': 0, 'data_random_seed': 0, 'bagging_fraction': 1.0, 'min_data_in_leaf': 100, 'max_bin': 255, 'objective': 'binary', 'bagging_freq': 1, 'metric': 'binary_logloss', 'min_sum_hessian_in_leaf': 10, 'feature_fraction': 1.0}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Default LightGBM result on test:
#
# For seed=0 Test's logloss : 0.397491
# For seed=1 Test's logloss : 0.397491
# For seed=2 Test's logloss : 0.397491
# For seed=3 Test's logloss : 0.397491
# For seed=4 Test's logloss : 0.397491
#
# Test's logloss mean: 0.397491, Test's logloss std: 0.000000
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Hyperopt iterations:
#
# [1/50]	eval_time=492.59 sec	current_logloss=0.398054	min_logloss=0.398054
# [2/50]	eval_time=158.55 sec	current_logloss=0.402286	min_logloss=0.398054
# [3/50]	eval_time=310.66 sec	current_logloss=0.397733	min_logloss=0.397733
# [4/50]	eval_time=145.80 sec	current_logloss=0.413637	min_logloss=0.397733
# [5/50]	eval_time=262.48 sec	current_logloss=0.399646	min_logloss=0.397733
# [6/50]	eval_time=849.48 sec	current_logloss=0.398159	min_logloss=0.397733
# [7/50]	eval_time=349.12 sec	current_logloss=0.397818	min_logloss=0.397733
# [8/50]	eval_time=155.37 sec	current_logloss=0.405554	min_logloss=0.397733
# [9/50]	eval_time=412.30 sec	current_logloss=0.398351	min_logloss=0.397733
# [10/50]	eval_time=552.85 sec	current_logloss=0.399801	min_logloss=0.397733
# [11/50]	eval_time=253.01 sec	current_logloss=0.398137	min_logloss=0.397733
# [12/50]	eval_time=714.61 sec	current_logloss=0.403387	min_logloss=0.397733
# [13/50]	eval_time=363.43 sec	current_logloss=0.401633	min_logloss=0.397733
# [14/50]	eval_time=166.68 sec	current_logloss=0.404393	min_logloss=0.397733
# [15/50]	eval_time=1016.78 sec	current_logloss=0.402626	min_logloss=0.397733
# [16/50]	eval_time=503.65 sec	current_logloss=0.408165	min_logloss=0.397733
# [17/50]	eval_time=265.01 sec	current_logloss=0.401716	min_logloss=0.397733
# [18/50]	eval_time=486.07 sec	current_logloss=0.397776	min_logloss=0.397733
# [19/50]	eval_time=999.45 sec	current_logloss=0.399214	min_logloss=0.397733
# [20/50]	eval_time=1117.34 sec	current_logloss=0.404674	min_logloss=0.397733
# [21/50]	eval_time=226.06 sec	current_logloss=0.397734	min_logloss=0.397733
# [22/50]	eval_time=224.26 sec	current_logloss=0.398030	min_logloss=0.397733
# [23/50]	eval_time=233.76 sec	current_logloss=0.397881	min_logloss=0.397733
# [24/50]	eval_time=219.97 sec	current_logloss=0.398507	min_logloss=0.397733
# [25/50]	eval_time=323.90 sec	current_logloss=0.402359	min_logloss=0.397733
# [26/50]	eval_time=182.95 sec	current_logloss=0.398011	min_logloss=0.397733
# [27/50]	eval_time=230.77 sec	current_logloss=0.397824	min_logloss=0.397733
# [28/50]	eval_time=362.45 sec	current_logloss=0.397788	min_logloss=0.397733
# [29/50]	eval_time=199.81 sec	current_logloss=0.399578	min_logloss=0.397733
# [30/50]	eval_time=165.13 sec	current_logloss=0.401961	min_logloss=0.397733
# [31/50]	eval_time=344.05 sec	current_logloss=0.397588	min_logloss=0.397588
# [32/50]	eval_time=402.23 sec	current_logloss=0.398559	min_logloss=0.397588
# [33/50]	eval_time=292.45 sec	current_logloss=0.397628	min_logloss=0.397588
# [34/50]	eval_time=317.41 sec	current_logloss=0.397912	min_logloss=0.397588
# [35/50]	eval_time=277.79 sec	current_logloss=0.397684	min_logloss=0.397588
# [36/50]	eval_time=340.45 sec	current_logloss=0.398173	min_logloss=0.397588
# [37/50]	eval_time=268.12 sec	current_logloss=0.397836	min_logloss=0.397588
# [38/50]	eval_time=660.36 sec	current_logloss=0.398837	min_logloss=0.397588
# [39/50]	eval_time=444.63 sec	current_logloss=0.397599	min_logloss=0.397588
# [40/50]	eval_time=516.77 sec	current_logloss=0.397644	min_logloss=0.397588
# [41/50]	eval_time=1453.05 sec	current_logloss=0.399215	min_logloss=0.397588
# [42/50]	eval_time=491.54 sec	current_logloss=0.397708	min_logloss=0.397588
# [43/50]	eval_time=849.98 sec	current_logloss=0.398543	min_logloss=0.397588
# [44/50]	eval_time=1413.90 sec	current_logloss=0.399685	min_logloss=0.397588
# [45/50]	eval_time=578.99 sec	current_logloss=0.399477	min_logloss=0.397588
# [46/50]	eval_time=281.22 sec	current_logloss=0.397952	min_logloss=0.397588
# [47/50]	eval_time=236.91 sec	current_logloss=0.397713	min_logloss=0.397588
# [48/50]	eval_time=253.31 sec	current_logloss=0.397500	min_logloss=0.397500
# [49/50]	eval_time=156.30 sec	current_logloss=0.401501	min_logloss=0.397500
# [50/50]	eval_time=236.79 sec	current_logloss=0.398331	min_logloss=0.397500
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned LightGBM result on cv:
#
# logloss = 0.397500389726
# best_n_estimators = 684
# params = {'num_leaves': 45, 'verbose': -1, 'bagging_seed': 0, 'metric': 'binary_logloss', 'data_random_seed': 0, 'min_data_in_leaf': 8, 'bagging_fraction': 0.8420658067233723, 'min_sum_hessian_in_leaf': 0.004549958246639956, 'feature_fraction_seed': 0, 'lambda_l1': 0.7677413533309505, 'bagging_freq': 1, 'lambda_l2': 0.10721553735236211, 'objective': 'binary', 'drop_seed': 0, 'learning_rate': 0.029263299622061, 'feature_fraction': 0.670232967018771}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned LightGBM result on test:
#
# For seed=0 Test's logloss : 0.396372
# For seed=1 Test's logloss : 0.396436
# For seed=2 Test's logloss : 0.396302
# For seed=3 Test's logloss : 0.396342
# For seed=4 Test's logloss : 0.396187
#
# Test's logloss mean: 0.396328, Test's logloss std: 0.000083

# %% [markdown]
# ## `CatBoost`

# %%
cab_default_test_result, cab_tuned_test_result = run_experiment(CABExperiment, "CatBoost")
# Out:
# Default CatBoost result on cv:
#
# logloss = 0.39299207788
# best_n_estimators = 3068
# params = {'rsm': 1.0, 'iterations': 3068, 'random_seed': 4, 'verbose': False, 'thread_count': 16, 'learning_rate': 0.03, 'ctr_description': ['Borders', 'CounterMax'], 'depth': 6, 'fold_len_multiplier': 2, 'loss_function': 'Logloss', 'ctr_border_count': 16, 'l2_leaf_reg': 3, 'leaf_estimation_method': 'Newton', 'gradient_iterations': 10, 'border_count': 128, 'used_ram_limit': 100000000000}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Default CatBoost result on test:
#
# For seed=0 Test's logloss : 0.391002
# For seed=1 Test's logloss : 0.391058
# For seed=2 Test's logloss : 0.391105
# For seed=3 Test's logloss : 0.391202
# For seed=4 Test's logloss : 0.391216
#
# Test's logloss mean: 0.391116, Test's logloss std: 0.000082
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Hyperopt iterations:
#
# [1/50]	eval_time=5658.93 sec	current_logloss=0.393076	min_logloss=0.393076
# [2/50]	eval_time=5534.65 sec	current_logloss=0.393837	min_logloss=0.393076
# [3/50]	eval_time=5292.09 sec	current_logloss=0.393744	min_logloss=0.393076
# [4/50]	eval_time=5637.59 sec	current_logloss=0.393184	min_logloss=0.393076
# [5/50]	eval_time=6090.89 sec	current_logloss=0.393486	min_logloss=0.393076
# [6/50]	eval_time=5647.25 sec	current_logloss=0.393052	min_logloss=0.393052
# [7/50]	eval_time=5631.67 sec	current_logloss=0.393103	min_logloss=0.393052
# [8/50]	eval_time=6199.72 sec	current_logloss=0.392978	min_logloss=0.392978
# [9/50]	eval_time=5391.42 sec	current_logloss=0.395868	min_logloss=0.392978
# [10/50]	eval_time=6262.27 sec	current_logloss=0.392975	min_logloss=0.392975
# [11/50]	eval_time=5522.08 sec	current_logloss=0.393269	min_logloss=0.392975
# [12/50]	eval_time=5705.23 sec	current_logloss=0.393107	min_logloss=0.392975
# [13/50]	eval_time=5630.83 sec	current_logloss=0.393074	min_logloss=0.392975
# [14/50]	eval_time=6168.08 sec	current_logloss=0.392976	min_logloss=0.392975
# [15/50]	eval_time=5683.73 sec	current_logloss=0.393415	min_logloss=0.392975
# [16/50]	eval_time=5967.28 sec	current_logloss=0.393927	min_logloss=0.392975
# [17/50]	eval_time=6049.75 sec	current_logloss=0.394150	min_logloss=0.392975
# [18/50]	eval_time=5645.63 sec	current_logloss=0.393215	min_logloss=0.392975
# [19/50]	eval_time=5563.15 sec	current_logloss=0.393346	min_logloss=0.392975
# [20/50]	eval_time=6128.93 sec	current_logloss=0.393431	min_logloss=0.392975
# [21/50]	eval_time=6310.54 sec	current_logloss=0.393165	min_logloss=0.392975
# [22/50]	eval_time=6279.57 sec	current_logloss=0.393354	min_logloss=0.392975
# [23/50]	eval_time=6247.71 sec	current_logloss=0.392856	min_logloss=0.392856
# [24/50]	eval_time=6238.51 sec	current_logloss=0.392984	min_logloss=0.392856
# [25/50]	eval_time=6238.58 sec	current_logloss=0.392818	min_logloss=0.392818
# [26/50]	eval_time=6288.11 sec	current_logloss=0.392895	min_logloss=0.392818
# [27/50]	eval_time=6061.41 sec	current_logloss=0.393763	min_logloss=0.392818
# [28/50]	eval_time=6248.63 sec	current_logloss=0.392853	min_logloss=0.392818
# [29/50]	eval_time=6065.81 sec	current_logloss=0.393716	min_logloss=0.392818
# [30/50]	eval_time=6289.61 sec	current_logloss=0.392959	min_logloss=0.392818
# [31/50]	eval_time=6070.88 sec	current_logloss=0.393704	min_logloss=0.392818
# [32/50]	eval_time=5953.51 sec	current_logloss=0.403209	min_logloss=0.392818
# [33/50]	eval_time=6221.95 sec	current_logloss=0.393186	min_logloss=0.392818
# [34/50]	eval_time=6235.07 sec	current_logloss=0.392978	min_logloss=0.392818
# [35/50]	eval_time=6122.39 sec	current_logloss=0.395511	min_logloss=0.392818
# [36/50]	eval_time=6131.73 sec	current_logloss=0.393386	min_logloss=0.392818
# [37/50]	eval_time=6253.60 sec	current_logloss=0.392901	min_logloss=0.392818
# [38/50]	eval_time=6241.00 sec	current_logloss=0.392892	min_logloss=0.392818
# [39/50]	eval_time=6301.38 sec	current_logloss=0.392902	min_logloss=0.392818
# [40/50]	eval_time=6203.13 sec	current_logloss=0.392911	min_logloss=0.392818
# [41/50]	eval_time=5996.26 sec	current_logloss=0.394674	min_logloss=0.392818
# [42/50]	eval_time=6211.52 sec	current_logloss=0.393225	min_logloss=0.392818
# [43/50]	eval_time=5477.48 sec	current_logloss=0.393546	min_logloss=0.392818
# [44/50]	eval_time=6283.92 sec	current_logloss=0.392944	min_logloss=0.392818
# [45/50]	eval_time=5610.54 sec	current_logloss=0.393079	min_logloss=0.392818
# [46/50]	eval_time=6228.82 sec	current_logloss=0.392919	min_logloss=0.392818
# [47/50]	eval_time=5675.83 sec	current_logloss=0.393674	min_logloss=0.392818
# [48/50]	eval_time=6238.56 sec	current_logloss=0.393109	min_logloss=0.392818
# [49/50]	eval_time=6045.85 sec	current_logloss=0.393999	min_logloss=0.392818
# [50/50]	eval_time=5648.28 sec	current_logloss=0.393315	min_logloss=0.392818
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned CatBoost result on cv:
#
# logloss = 0.3928179242
# best_n_estimators = 4935
# params = {'random_seed': 4, 'verbose': False, 'thread_count': 16, 'learning_rate': 0.019745754754732805, 'ctr_border_count': 16, 'ctr_description': ('Borders', 'CounterMax'), 'iterations': 4935, 'one_hot_max_size': 0, 'bagging_temperature': 0.4099795494742011, 'gradient_iterations': 10, 'random_strength': 20, 'depth': 6, 'loss_function': 'Logloss', 'l2_leaf_reg': 6.296602917920105, 'border_count': 128, 'used_ram_limit': 100000000000}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned CatBoost result on test:
#
# For seed=0 Test's logloss : 0.390765
# For seed=1 Test's logloss : 0.390917
# For seed=2 Test's logloss : 0.390774
# For seed=3 Test's logloss : 0.391001
# For seed=4 Test's logloss : 0.391054
#
# Test's logloss mean: 0.390902, Test's logloss std: 0.000117

# %% [markdown]
# ## Comparing results
#
# The final table with metric values on the test dataset.

# %%
import pandas as pd
import numpy as np
from IPython.display import HTML, display
# %pylab inline --no-import-all

test_results = np.array([
    (xgb_default_test_result, xgb_tuned_test_result),
    (lgb_default_test_result, lgb_tuned_test_result),
    (cab_default_test_result, cab_tuned_test_result)
])

diff = 100 * test_results / test_results[2,1] - 100

res = [['{:.6f} ({:+.2f}%)'.format(test_results[i, j], diff[i, j]) for j in range(2)] for i in range(3)]

display(HTML(pd.DataFrame(res, columns=['default', 'tuned'], index=['xgboost', 'lightgbm', 'catboost']).to_html()))

results = [
    ('Tuned CatBoost',   cab_tuned_test_result),
    ('Default CatBoost', cab_default_test_result),
    ('Tuned XGBoost',    xgb_tuned_test_result),
    ('Default XGBoost',  xgb_default_test_result),
    ('Tuned LightGBM',   lgb_tuned_test_result),
    ('Default LightGBM', lgb_default_test_result),
]
names = ['%s\n%.5f' % (name, loss) for name, loss in results]

plt.figure(figsize=(20, 7))
plt.scatter(range(6), zip(*results)[1], s=150)
plt.xticks(range(6), names, fontsize=15)
plt.yticks(fontsize=12)
plt.title('Comparison', fontsize=20)
plt.ylabel(experiment.metric, fontsize=16);
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>default</th>
#       <th>tuned</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>xgboost</th>
#       <td>0.397638 (+1.72%)</td>
#       <td>0.396242 (+1.37%)</td>
#     </tr>
#     <tr>
#       <th>lightgbm</th>
#       <td>0.397491 (+1.69%)</td>
#       <td>0.396328 (+1.39%)</td>
#     </tr>
#     <tr>
#       <th>catboost</th>
#       <td>0.391116 (+0.05%)</td>
#       <td>0.390902 (+0.00%)</td>
#     </tr>
#   </tbody>
# </table>
