# %% [markdown]
# # Comparing algorithms on the Upsel dataset
# The data is taken from [this source](http://www.kdd.org/kdd-cup/view/kdd-cup-2009/Data).

# %% [markdown]
# For details on running the comparison, see [this article](https://github.com/catboost/benchmarks/blob/master/comparison_description.pdf).

# %%
from experiment import Experiment
from xgboost_experiment import XGBExperiment
from lightgbm_experiment import LGBExperiment
from catboost_experiment import CABExperiment

# %% [markdown]
# Load the dataset and set parameters for the experiment.

# %%
learning_task = 'classification'
dataset_path = '/media/pool_storage/tsnet-pools-converted/upsel/'
n_estimators = 5000
max_hyperopt_evals = 50

experiment = Experiment(learning_task, train_path=dataset_path + 'train_full3',
                        test_path=dataset_path + 'test3', cd_path = dataset_path + 'train_full3.cd')
X_train, y_train, X_test, y_test, cat_cols = experiment.read_data()

# %% [markdown]
# Write a function that does the following:
#
# **Preprocess the dataset:**
# calculate counter values on the training set, transform cat features (for the `XGBoost` and `LightGBM` algorithms), and convert the data to the format of the algorithm. Do the same thing with all pairs after splitting them into cross validation folds.
#
# **Select the optimal number of trees for the algorithm with the default parameters:** for each fold and each number of trees, get the result of the algorithm trained on the other four folds, average the results for each number of trees, and choose the best one.
#
# **Assess the quality of the algorithm with the default parameters on a test dataset:** train the algorithm with the number of trees obtained in the previous step, and calculate the metric value on the test dataset.
#
# **Tune parameters for the algorithm using `Hyperopt`:** on each `Hyperopt` iteration of the algorithm, the best value of trees is selected and the metric for cross validation is calculated.
#
# **Show results on the test dataset for the algorithm with the tuned parameters:** train the algorithm with the optimal parameters and the number of trees obtained in the previous step, and calculate the metric value on the test dataset.

# %%
import numpy as np

def run_experiment(Experiment, title):
    experiment = Experiment(learning_task, max_hyperopt_evals=max_hyperopt_evals,
                            n_estimators=n_estimators)
    cv_pairs, (dtrain, dtest) = experiment.split_and_preprocess(X_train.copy(), y_train, 
                                                                X_test.copy(), y_test, 
                                                                cat_cols, n_splits=5)
 
    default_cv_result = experiment.run_cv(cv_pairs)
    experiment.print_result(default_cv_result, 'Default {} result on cv'.format(title))

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')

    default_test_losses = []
    for seed in range(5):
        test_result = experiment.run_test(dtrain, dtest, X_test, params=default_cv_result['params'],
                                          n_estimators=default_cv_result['best_n_estimators'], seed=seed)
        default_test_losses.append(test_result['loss'])
        print 'For seed=%d Test\'s %s : %.5f' % (seed, experiment.metric, default_test_losses[-1])
    print '\nTest\'s %s mean: %.5f, Test\'s %s std: %.5f' % (experiment.metric, np.mean(default_test_losses),
                                                             experiment.metric, np.std(default_test_losses))

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')
    print('Hyperopt iterations:\n\n')

    tuned_cv_result = experiment.optimize_params(cv_pairs)

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')

    experiment.print_result(tuned_cv_result, 'Tuned {} result on cv'.format(title))

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')

    tuned_test_losses = []
    for seed in range(5):
        test_result = experiment.run_test(dtrain, dtest, X_test, params=tuned_cv_result['params'],
                                          n_estimators=tuned_cv_result['best_n_estimators'], seed=seed)
        tuned_test_losses.append(test_result['loss'])
        print 'For seed=%d Test\'s %s : %.5f' % (seed, experiment.metric, tuned_test_losses[-1])
    print '\nTest\'s %s mean: %.5f, Test\'s %s std: %.5f' % (experiment.metric, np.mean(tuned_test_losses),
                                                             experiment.metric, np.std(tuned_test_losses))

    return np.mean(default_test_losses), np.mean(tuned_test_losses)

# %% [markdown]
# ## `XGBoost`

# %%
xgb_default_test_result, xgb_tuned_test_result = run_experiment(XGBExperiment, "XGBoost")
# Out:
# Default XGBoost result on cv:
#
# logloss = 0.168292
# best_n_estimators = 19
# params = {'colsample_bytree': 1.0, 'silent': 1, 'eval_metric': 'logloss', 'colsample_bylevel': 1.0, 'min_child_weight': 1, 'subsample': 1.0, 'eta': 0.3, 'objective': 'binary:logistic', 'alpha': 0, 'seed': 0, 'max_depth': 6, 'gamma': 0, 'lambda': 1}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Default XGBoost result on test:
#
# For seed=0 Test's logloss : 0.168732
# For seed=1 Test's logloss : 0.168732
# For seed=2 Test's logloss : 0.168732
# For seed=3 Test's logloss : 0.168732
# For seed=4 Test's logloss : 0.168732
#
# Test's logloss mean: 0.168732, Test's logloss std: 0.000000
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Hyperopt iterations:
#
# [1/50]	eval_time=1109.59 sec	current_logloss=0.166177	min_logloss=0.166177
# [2/50]	eval_time=1266.06 sec	current_logloss=0.166330	min_logloss=0.166177
# [3/50]	eval_time=522.45 sec	current_logloss=0.173621	min_logloss=0.166177
# [4/50]	eval_time=528.56 sec	current_logloss=0.166352	min_logloss=0.166177
# [5/50]	eval_time=682.87 sec	current_logloss=0.166513	min_logloss=0.166177
# [6/50]	eval_time=798.86 sec	current_logloss=0.166076	min_logloss=0.166076
# [7/50]	eval_time=735.07 sec	current_logloss=0.193781	min_logloss=0.166076
# [8/50]	eval_time=1198.08 sec	current_logloss=0.165878	min_logloss=0.165878
# [9/50]	eval_time=755.86 sec	current_logloss=0.166363	min_logloss=0.165878
# [10/50]	eval_time=2138.40 sec	current_logloss=0.168407	min_logloss=0.165878
# [11/50]	eval_time=485.04 sec	current_logloss=0.168215	min_logloss=0.165878
# [12/50]	eval_time=1143.79 sec	current_logloss=0.168796	min_logloss=0.165878
# [13/50]	eval_time=661.75 sec	current_logloss=0.168747	min_logloss=0.165878
# [14/50]	eval_time=884.70 sec	current_logloss=0.165998	min_logloss=0.165878
# [15/50]	eval_time=1522.67 sec	current_logloss=0.167609	min_logloss=0.165878
# [16/50]	eval_time=816.55 sec	current_logloss=0.165705	min_logloss=0.165705
# [17/50]	eval_time=1240.97 sec	current_logloss=0.166532	min_logloss=0.165705
# [18/50]	eval_time=399.63 sec	current_logloss=0.165938	min_logloss=0.165705
# [19/50]	eval_time=335.76 sec	current_logloss=0.166352	min_logloss=0.165705
# [20/50]	eval_time=537.54 sec	current_logloss=0.169935	min_logloss=0.165705
# [21/50]	eval_time=926.83 sec	current_logloss=0.168268	min_logloss=0.165705
# [22/50]	eval_time=734.05 sec	current_logloss=0.167298	min_logloss=0.165705
# [23/50]	eval_time=1079.25 sec	current_logloss=0.165721	min_logloss=0.165705
# [24/50]	eval_time=1114.57 sec	current_logloss=0.166553	min_logloss=0.165705
# [25/50]	eval_time=1718.22 sec	current_logloss=0.166486	min_logloss=0.165705
# [26/50]	eval_time=811.50 sec	current_logloss=0.166077	min_logloss=0.165705
# [27/50]	eval_time=906.30 sec	current_logloss=0.165991	min_logloss=0.165705
# [28/50]	eval_time=1830.23 sec	current_logloss=0.167492	min_logloss=0.165705
# [29/50]	eval_time=574.12 sec	current_logloss=0.168388	min_logloss=0.165705
# [30/50]	eval_time=1145.49 sec	current_logloss=0.166658	min_logloss=0.165705
# [31/50]	eval_time=1531.51 sec	current_logloss=0.166456	min_logloss=0.165705
# [32/50]	eval_time=1077.36 sec	current_logloss=0.165939	min_logloss=0.165705
# [33/50]	eval_time=684.25 sec	current_logloss=0.171812	min_logloss=0.165705
# [34/50]	eval_time=1056.16 sec	current_logloss=0.166457	min_logloss=0.165705
# [35/50]	eval_time=968.14 sec	current_logloss=0.167889	min_logloss=0.165705
# [36/50]	eval_time=868.50 sec	current_logloss=0.165544	min_logloss=0.165544
# [37/50]	eval_time=626.58 sec	current_logloss=0.165909	min_logloss=0.165544
# [38/50]	eval_time=1140.36 sec	current_logloss=0.166155	min_logloss=0.165544
# [39/50]	eval_time=609.83 sec	current_logloss=0.165690	min_logloss=0.165544
# [40/50]	eval_time=511.22 sec	current_logloss=0.166392	min_logloss=0.165544
# [41/50]	eval_time=541.84 sec	current_logloss=0.165621	min_logloss=0.165544
# [42/50]	eval_time=310.41 sec	current_logloss=0.183381	min_logloss=0.165544
# [43/50]	eval_time=710.57 sec	current_logloss=0.165777	min_logloss=0.165544
# [44/50]	eval_time=361.32 sec	current_logloss=0.171408	min_logloss=0.165544
# [45/50]	eval_time=821.40 sec	current_logloss=0.165736	min_logloss=0.165544
# [46/50]	eval_time=843.85 sec	current_logloss=0.167006	min_logloss=0.165544
# [47/50]	eval_time=422.73 sec	current_logloss=0.166354	min_logloss=0.165544
# [48/50]	eval_time=774.63 sec	current_logloss=0.165745	min_logloss=0.165544
# [49/50]	eval_time=595.86 sec	current_logloss=0.165667	min_logloss=0.165544
# [50/50]	eval_time=611.25 sec	current_logloss=0.165732	min_logloss=0.165544
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned XGBoost result on cv:
#
# logloss = 0.1655438
# best_n_estimators = 3404
# params = {'colsample_bytree': 0.5142241178588046, 'silent': 1, 'eval_metric': 'logloss', 'colsample_bylevel': 0.8960123714513979, 'min_child_weight': 4.119534140591444, 'subsample': 0.7702739765545289, 'eta': 0.0028948314578000943, 'objective': 'binary:logistic', 'alpha': 0.0002204110120151732, 'seed': 0, 'max_depth': 5, 'gamma': 0, 'lambda': 0.06714950385666829}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned XGBoost result on test:
#
# For seed=0 Test's logloss : 0.166211
# For seed=1 Test's logloss : 0.166378
# For seed=2 Test's logloss : 0.166243
# For seed=3 Test's logloss : 0.166414
# For seed=4 Test's logloss : 0.166365
#
# Test's logloss mean: 0.166322, Test's logloss std: 0.000080

# %% [markdown]
# ## `LightGBM`

# %%
lgb_default_test_result, lgb_tuned_test_result = run_experiment(LGBExperiment, "LightGBM")
# Out:
# Default LightGBM result on cv:
#
# logloss = 0.169915585574
# best_n_estimators = 46
# params = {'feature_fraction_seed': 0, 'num_leaves': 127, 'verbose': -1, 'bagging_seed': 0, 'lambda_l1': 0, 'drop_seed': 0, 'learning_rate': 0.1, 'lambda_l2': 0, 'data_random_seed': 0, 'bagging_fraction': 1.0, 'min_data_in_leaf': 100, 'max_bin': 255, 'objective': 'binary', 'bagging_freq': 1, 'metric': 'binary_logloss', 'min_sum_hessian_in_leaf': 10, 'feature_fraction': 1.0}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Default LightGBM result on test:
#
# For seed=0 Test's logloss : 0.171071
# For seed=1 Test's logloss : 0.171071
# For seed=2 Test's logloss : 0.171071
# For seed=3 Test's logloss : 0.171071
# For seed=4 Test's logloss : 0.171071
#
# Test's logloss mean: 0.171071, Test's logloss std: 0.000000
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Hyperopt iterations:
#
# [1/50]	eval_time=185.40 sec	current_logloss=0.168107	min_logloss=0.168107
# [2/50]	eval_time=91.60 sec	current_logloss=0.169142	min_logloss=0.168107
# [3/50]	eval_time=314.28 sec	current_logloss=0.166033	min_logloss=0.166033
# [4/50]	eval_time=72.50 sec	current_logloss=0.172942	min_logloss=0.166033
# [5/50]	eval_time=185.08 sec	current_logloss=0.174148	min_logloss=0.166033
# [6/50]	eval_time=1869.90 sec	current_logloss=0.173573	min_logloss=0.166033
# [7/50]	eval_time=346.91 sec	current_logloss=0.167157	min_logloss=0.166033
# [8/50]	eval_time=84.17 sec	current_logloss=0.167404	min_logloss=0.166033
# [9/50]	eval_time=144.31 sec	current_logloss=0.167216	min_logloss=0.166033
# [10/50]	eval_time=208.84 sec	current_logloss=0.171702	min_logloss=0.166033
# [11/50]	eval_time=212.01 sec	current_logloss=0.165917	min_logloss=0.165917
# [12/50]	eval_time=245.32 sec	current_logloss=0.184190	min_logloss=0.165917
# [13/50]	eval_time=207.18 sec	current_logloss=0.187256	min_logloss=0.165917
# [14/50]	eval_time=101.48 sec	current_logloss=0.167057	min_logloss=0.165917
# [15/50]	eval_time=115.17 sec	current_logloss=0.171364	min_logloss=0.165917
# [16/50]	eval_time=99.63 sec	current_logloss=0.276476	min_logloss=0.165917
# [17/50]	eval_time=101.47 sec	current_logloss=0.174264	min_logloss=0.165917
# [18/50]	eval_time=1007.76 sec	current_logloss=0.168861	min_logloss=0.165917
# [19/50]	eval_time=770.01 sec	current_logloss=0.176365	min_logloss=0.165917
# [20/50]	eval_time=256.52 sec	current_logloss=0.178107	min_logloss=0.165917
# [21/50]	eval_time=205.61 sec	current_logloss=0.165957	min_logloss=0.165917
# [22/50]	eval_time=221.18 sec	current_logloss=0.165930	min_logloss=0.165917
# [23/50]	eval_time=158.91 sec	current_logloss=0.165270	min_logloss=0.165270
# [24/50]	eval_time=132.25 sec	current_logloss=0.165636	min_logloss=0.165270
# [25/50]	eval_time=116.88 sec	current_logloss=0.165638	min_logloss=0.165270
# [26/50]	eval_time=111.99 sec	current_logloss=0.165405	min_logloss=0.165270
# [27/50]	eval_time=79.14 sec	current_logloss=0.168955	min_logloss=0.165270
# [28/50]	eval_time=104.95 sec	current_logloss=0.165799	min_logloss=0.165270
# [29/50]	eval_time=87.83 sec	current_logloss=0.168977	min_logloss=0.165270
# [30/50]	eval_time=204.01 sec	current_logloss=0.166264	min_logloss=0.165270
# [31/50]	eval_time=127.44 sec	current_logloss=0.165552	min_logloss=0.165270
# [32/50]	eval_time=82.98 sec	current_logloss=0.185413	min_logloss=0.165270
# [33/50]	eval_time=193.39 sec	current_logloss=0.166191	min_logloss=0.165270
# [34/50]	eval_time=293.54 sec	current_logloss=0.167380	min_logloss=0.165270
# [35/50]	eval_time=115.59 sec	current_logloss=0.165875	min_logloss=0.165270
# [36/50]	eval_time=128.04 sec	current_logloss=0.165931	min_logloss=0.165270
# [37/50]	eval_time=82.57 sec	current_logloss=0.169973	min_logloss=0.165270
# [38/50]	eval_time=67.12 sec	current_logloss=0.169318	min_logloss=0.165270
# [39/50]	eval_time=371.56 sec	current_logloss=0.165839	min_logloss=0.165270
# [40/50]	eval_time=197.09 sec	current_logloss=0.165961	min_logloss=0.165270
# [41/50]	eval_time=110.23 sec	current_logloss=0.165622	min_logloss=0.165270
# [42/50]	eval_time=93.04 sec	current_logloss=0.169268	min_logloss=0.165270
# [43/50]	eval_time=134.23 sec	current_logloss=0.166779	min_logloss=0.165270
# [44/50]	eval_time=217.91 sec	current_logloss=0.166503	min_logloss=0.165270
# [45/50]	eval_time=356.04 sec	current_logloss=0.166914	min_logloss=0.165270
# [46/50]	eval_time=149.73 sec	current_logloss=0.167173	min_logloss=0.165270
# [47/50]	eval_time=89.93 sec	current_logloss=0.173640	min_logloss=0.165270
# [48/50]	eval_time=200.34 sec	current_logloss=0.165475	min_logloss=0.165270
# [49/50]	eval_time=218.21 sec	current_logloss=0.188438	min_logloss=0.165270
# [50/50]	eval_time=169.27 sec	current_logloss=0.166935	min_logloss=0.165270
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned LightGBM result on cv:
#
# logloss = 0.165270067235
# best_n_estimators = 2435
# params = {'num_leaves': 11, 'verbose': -1, 'bagging_seed': 0, 'metric': 'binary_logloss', 'data_random_seed': 0, 'min_data_in_leaf': 109, 'bagging_fraction': 0.8965102673774312, 'min_sum_hessian_in_leaf': 1.0201871963154937e-05, 'feature_fraction_seed': 0, 'lambda_l1': 0.006143582721183149, 'bagging_freq': 1, 'lambda_l2': 0, 'objective': 'binary', 'drop_seed': 0, 'learning_rate': 0.004440192867499371, 'feature_fraction': 0.5804298705452275}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned LightGBM result on test:
#
# For seed=0 Test's logloss : 0.166812
# For seed=1 Test's logloss : 0.166765
# For seed=2 Test's logloss : 0.166819
# For seed=3 Test's logloss : 0.166815
# For seed=4 Test's logloss : 0.166881
#
# Test's logloss mean: 0.166818, Test's logloss std: 0.000037

# %% [markdown]
# ## `CatBoost`

# %%
cab_default_test_result, cab_tuned_test_result = run_experiment(CABExperiment, "CatBoost")
# Out:
# Default CatBoost result on cv:
#
# logloss = 0.16560400452
# best_n_estimators = 1063
# params = {'rsm': 1.0, 'iterations': 1063, 'random_seed': 4, 'verbose': False, 'thread_count': 16, 'learning_rate': 0.03, 'ctr_description': ['Borders', 'CounterMax'], 'depth': 6, 'fold_len_multiplier': 2, 'loss_function': 'Logloss', 'ctr_border_count': 16, 'l2_leaf_reg': 3, 'leaf_estimation_method': 'Newton', 'gradient_iterations': 10, 'border_count': 128, 'used_ram_limit': 100000000000}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Default CatBoost result on test:
#
# For seed=0 Test's logloss : 0.166629
# For seed=1 Test's logloss : 0.166598
# For seed=2 Test's logloss : 0.166552
# For seed=3 Test's logloss : 0.166930
# For seed=4 Test's logloss : 0.167002
#
# Test's logloss mean: 0.166742, Test's logloss std: 0.000186
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Hyperopt iterations:
#
# [1/50]	eval_time=1950.90 sec	current_logloss=0.165578	min_logloss=0.165578
# [2/50]	eval_time=2943.18 sec	current_logloss=0.167015	min_logloss=0.165578
# [3/50]	eval_time=1906.24 sec	current_logloss=0.165714	min_logloss=0.165578
# [4/50]	eval_time=1935.98 sec	current_logloss=0.165628	min_logloss=0.165578
# [5/50]	eval_time=2883.03 sec	current_logloss=0.165692	min_logloss=0.165578
# [6/50]	eval_time=1944.52 sec	current_logloss=0.165778	min_logloss=0.165578
# [7/50]	eval_time=1956.83 sec	current_logloss=0.165617	min_logloss=0.165578
# [8/50]	eval_time=2112.11 sec	current_logloss=0.165699	min_logloss=0.165578
# [9/50]	eval_time=2978.84 sec	current_logloss=0.169377	min_logloss=0.165578
# [10/50]	eval_time=3081.00 sec	current_logloss=0.165829	min_logloss=0.165578
# [11/50]	eval_time=2847.01 sec	current_logloss=0.165368	min_logloss=0.165368
# [12/50]	eval_time=2988.67 sec	current_logloss=0.165769	min_logloss=0.165368
# [13/50]	eval_time=1938.42 sec	current_logloss=0.165722	min_logloss=0.165368
# [14/50]	eval_time=2087.65 sec	current_logloss=0.165846	min_logloss=0.165368
# [15/50]	eval_time=2937.21 sec	current_logloss=0.165692	min_logloss=0.165368
# [16/50]	eval_time=2155.89 sec	current_logloss=0.167389	min_logloss=0.165368
# [17/50]	eval_time=3154.66 sec	current_logloss=0.167095	min_logloss=0.165368
# [18/50]	eval_time=2905.41 sec	current_logloss=0.165357	min_logloss=0.165357
# [19/50]	eval_time=1944.30 sec	current_logloss=0.166026	min_logloss=0.165357
# [20/50]	eval_time=2138.04 sec	current_logloss=0.166117	min_logloss=0.165357
# [21/50]	eval_time=2930.86 sec	current_logloss=0.165828	min_logloss=0.165357
# [22/50]	eval_time=2892.73 sec	current_logloss=0.165535	min_logloss=0.165357
# [23/50]	eval_time=2841.50 sec	current_logloss=0.165652	min_logloss=0.165357
# [24/50]	eval_time=2901.48 sec	current_logloss=0.165483	min_logloss=0.165357
# [25/50]	eval_time=2931.85 sec	current_logloss=0.165895	min_logloss=0.165357
# [26/50]	eval_time=2980.43 sec	current_logloss=0.167929	min_logloss=0.165357
# [27/50]	eval_time=2910.95 sec	current_logloss=0.165547	min_logloss=0.165357
# [28/50]	eval_time=2901.58 sec	current_logloss=0.165491	min_logloss=0.165357
# [29/50]	eval_time=2925.50 sec	current_logloss=0.165553	min_logloss=0.165357
# [30/50]	eval_time=2988.88 sec	current_logloss=0.167200	min_logloss=0.165357
# [31/50]	eval_time=2908.02 sec	current_logloss=0.165782	min_logloss=0.165357
# [32/50]	eval_time=2929.67 sec	current_logloss=0.165667	min_logloss=0.165357
# [33/50]	eval_time=2942.13 sec	current_logloss=0.165766	min_logloss=0.165357
# [34/50]	eval_time=2930.79 sec	current_logloss=0.165374	min_logloss=0.165357
# [35/50]	eval_time=2713.56 sec	current_logloss=0.165841	min_logloss=0.165357
# [36/50]	eval_time=3060.81 sec	current_logloss=0.165735	min_logloss=0.165357
# [37/50]	eval_time=2890.91 sec	current_logloss=0.165517	min_logloss=0.165357
# [38/50]	eval_time=2884.93 sec	current_logloss=0.165767	min_logloss=0.165357
# [39/50]	eval_time=3011.89 sec	current_logloss=0.165575	min_logloss=0.165357
# [40/50]	eval_time=1939.64 sec	current_logloss=0.165573	min_logloss=0.165357
# [41/50]	eval_time=2935.17 sec	current_logloss=0.165683	min_logloss=0.165357
# [42/50]	eval_time=2888.67 sec	current_logloss=0.165676	min_logloss=0.165357
# [43/50]	eval_time=1934.58 sec	current_logloss=0.165857	min_logloss=0.165357
# [44/50]	eval_time=2939.06 sec	current_logloss=0.165825	min_logloss=0.165357
# [45/50]	eval_time=2055.97 sec	current_logloss=0.165827	min_logloss=0.165357
# [46/50]	eval_time=2933.49 sec	current_logloss=0.165554	min_logloss=0.165357
# [47/50]	eval_time=2858.51 sec	current_logloss=0.165407	min_logloss=0.165357
# [48/50]	eval_time=2133.91 sec	current_logloss=0.166223	min_logloss=0.165357
# [49/50]	eval_time=3035.73 sec	current_logloss=0.165652	min_logloss=0.165357
# [50/50]	eval_time=2966.41 sec	current_logloss=0.165625	min_logloss=0.165357
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned CatBoost result on cv:
#
# logloss = 0.16535673894
# best_n_estimators = 3243
# params = {'random_seed': 4, 'verbose': False, 'thread_count': 16, 'learning_rate': 0.011604777635943067, 'ctr_border_count': 16, 'ctr_description': ('Borders', 'CounterMax'), 'iterations': 3243, 'one_hot_max_size': 0, 'bagging_temperature': 0.5203813091067112, 'gradient_iterations': 1, 'random_strength': 1, 'depth': 6, 'loss_function': 'Logloss', 'l2_leaf_reg': 1.002270104283921, 'border_count': 128, 'used_ram_limit': 100000000000}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned CatBoost result on test:
#
# For seed=0 Test's logloss : 0.165825
# For seed=1 Test's logloss : 0.166383
# For seed=2 Test's logloss : 0.166150
# For seed=3 Test's logloss : 0.165949
# For seed=4 Test's logloss : 0.166336
#
# Test's logloss mean: 0.166128, Test's logloss std: 0.000216

# %% [markdown]
# ## Comparing results
#
# The final table with metric values on the test dataset.

# %%
import pandas as pd
import numpy as np
from IPython.display import HTML, display
# %pylab inline --no-import-all

test_results = np.array([
    (xgb_default_test_result, xgb_tuned_test_result),
    (lgb_default_test_result, lgb_tuned_test_result),
    (cab_default_test_result, cab_tuned_test_result)
])

diff = 100 * test_results / test_results[2,1] - 100

res = [['{:.6f} ({:+.2f}%)'.format(test_results[i, j], diff[i, j]) for j in range(2)] for i in range(3)]

display(HTML(pd.DataFrame(res, columns=['default', 'tuned'], index=['xgboost', 'lightgbm', 'catboost']).to_html()))

results = [
    ('Tuned CatBoost',   cab_tuned_test_result),
    ('Default CatBoost', cab_default_test_result),
    ('Tuned XGBoost',    xgb_tuned_test_result),
    ('Default XGBoost',  xgb_default_test_result),
    ('Tuned LightGBM',   lgb_tuned_test_result),
    ('Default LightGBM', lgb_default_test_result),
]
names = ['%s\n%.5f' % (name, loss) for name, loss in results]

plt.figure(figsize=(20, 7))
plt.scatter(range(6), zip(*results)[1], s=150)
plt.xticks(range(6), names, fontsize=15)
plt.yticks(fontsize=12)
plt.title('Comparison', fontsize=20)
plt.ylabel(experiment.metric, fontsize=16);
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>default</th>
#       <th>tuned</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>xgboost</th>
#       <td>0.168732 (+1.57%)</td>
#       <td>0.166322 (+0.12%)</td>
#     </tr>
#     <tr>
#       <th>lightgbm</th>
#       <td>0.171071 (+2.98%)</td>
#       <td>0.166818 (+0.42%)</td>
#     </tr>
#     <tr>
#       <th>catboost</th>
#       <td>0.166742 (+0.37%)</td>
#       <td>0.166128 (+0.00%)</td>
#     </tr>
#   </tbody>
# </table>
