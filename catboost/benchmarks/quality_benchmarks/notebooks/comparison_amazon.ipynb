# %% [markdown]
# # Comparing algorithms on the Amazon dataset
# The data is taken from [this source](https://www.kaggle.com/c/amazon-employee-access-challenge).

# %% [markdown]
# For details on running the comparison, see [this article](https://github.com/catboost/benchmarks/blob/master/comparison_description.pdf).

# %%
from experiment import Experiment
from xgboost_experiment import XGBExperiment
from lightgbm_experiment import LGBExperiment
from catboost_experiment import CABExperiment

# %% [markdown]
# Load the dataset and set parameters for the experiment.

# %%
learning_task = 'classification'
dataset_path = '/media/pool_storage/tsnet-pools-converted/amazon/'
n_estimators = 5000
max_hyperopt_evals = 50

experiment = Experiment(learning_task, train_path=dataset_path + 'train_full3',
                        test_path=dataset_path + 'test3', cd_path = dataset_path + 'train_full3.cd')
X_train, y_train, X_test, y_test, cat_cols = experiment.read_data()

# %% [markdown]
# Write a function that does the following:
#
# **Preprocess the dataset:**
# calculate counter values on the training set, transform cat features (for the `XGBoost` and `LightGBM` algorithms), and convert the data to the format of the algorithm. Do the same thing with all pairs after splitting them into cross validation folds.
#
# **Select the optimal number of trees for the algorithm with the default parameters:** for each fold and each number of trees, get the result of the algorithm trained on the other four folds, average the results for each number of trees, and choose the best one.
#
# **Assess the quality of the algorithm with the default parameters on a test dataset:** train the algorithm with the number of trees obtained in the previous step, and calculate the metric value on the test dataset.
#
# **Tune parameters for the algorithm using `Hyperopt`:** on each `Hyperopt` iteration of the algorithm, the best value of trees is selected and the metric for cross validation is calculated.
#
# **Show results on the test dataset for the algorithm with the tuned parameters:** train the algorithm with the optimal parameters and the number of trees obtained in the previous step, and calculate the metric value on the test dataset.

# %%
import numpy as np

def run_experiment(Experiment, title):
    experiment = Experiment(learning_task, max_hyperopt_evals=max_hyperopt_evals,
                            n_estimators=n_estimators)
    cv_pairs, (dtrain, dtest) = experiment.split_and_preprocess(X_train.copy(), y_train, 
                                                                X_test.copy(), y_test, 
                                                                cat_cols, n_splits=5)
 
    default_cv_result = experiment.run_cv(cv_pairs)
    experiment.print_result(default_cv_result, 'Default {} result on cv'.format(title))

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')

    default_test_losses = []
    for seed in range(5):
        test_result = experiment.run_test(dtrain, dtest, X_test, params=default_cv_result['params'],
                                          n_estimators=default_cv_result['best_n_estimators'], seed=seed)
        default_test_losses.append(test_result['loss'])
        print 'For seed=%d Test\'s %s : %.5f' % (seed, experiment.metric, default_test_losses[-1])
    print '\nTest\'s %s mean: %.5f, Test\'s %s std: %.5f' % (experiment.metric, np.mean(default_test_losses),
                                                             experiment.metric, np.std(default_test_losses))

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')
    print('Hyperopt iterations:\n\n')

    tuned_cv_result = experiment.optimize_params(cv_pairs)

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')

    experiment.print_result(tuned_cv_result, 'Tuned {} result on cv'.format(title))

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')

    tuned_test_losses = []
    for seed in range(5):
        test_result = experiment.run_test(dtrain, dtest, X_test, params=tuned_cv_result['params'],
                                          n_estimators=tuned_cv_result['best_n_estimators'], seed=seed)
        tuned_test_losses.append(test_result['loss'])
        print 'For seed=%d Test\'s %s : %.5f' % (seed, experiment.metric, tuned_test_losses[-1])
    print '\nTest\'s %s mean: %.5f, Test\'s %s std: %.5f' % (experiment.metric, np.mean(tuned_test_losses),
                                                             experiment.metric, np.std(tuned_test_losses))

    return np.mean(default_test_losses), np.mean(tuned_test_losses)

# %% [markdown]
# ## `XGBoost`

# %%
xgb_default_test_result, xgb_tuned_test_result = run_experiment(XGBExperiment, "XGBoost")
# Out:
# Default XGBoost result on cv:
#
# logloss = 0.1766994
# best_n_estimators = 17
# params = {'colsample_bytree': 1.0, 'silent': 1, 'eval_metric': 'logloss', 'colsample_bylevel': 1.0, 'min_child_weight': 1, 'subsample': 1.0, 'eta': 0.3, 'objective': 'binary:logistic', 'alpha': 0, 'seed': 0, 'max_depth': 6, 'gamma': 0, 'lambda': 1}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Default XGBoost result on test:
#
# For seed=0 Test's logloss : 0.165365
# For seed=1 Test's logloss : 0.165365
# For seed=2 Test's logloss : 0.165365
# For seed=3 Test's logloss : 0.165365
# For seed=4 Test's logloss : 0.165365
#
# Test's logloss mean: 0.165365, Test's logloss std: 0.000000
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Hyperopt iterations:
#
# [1/50]	eval_time=102.97 sec	current_logloss=0.174337	min_logloss=0.174337
# [2/50]	eval_time=147.25 sec	current_logloss=0.173153	min_logloss=0.173153
# [3/50]	eval_time=86.30 sec	current_logloss=0.184827	min_logloss=0.173153
# [4/50]	eval_time=73.78 sec	current_logloss=0.174250	min_logloss=0.173153
# [5/50]	eval_time=77.50 sec	current_logloss=0.176848	min_logloss=0.173153
# [6/50]	eval_time=81.01 sec	current_logloss=0.175261	min_logloss=0.173153
# [7/50]	eval_time=41.72 sec	current_logloss=0.203173	min_logloss=0.173153
# [8/50]	eval_time=138.95 sec	current_logloss=0.173412	min_logloss=0.173153
# [9/50]	eval_time=107.43 sec	current_logloss=0.178139	min_logloss=0.173153
# [10/50]	eval_time=228.41 sec	current_logloss=0.174668	min_logloss=0.173153
# [11/50]	eval_time=71.27 sec	current_logloss=0.181075	min_logloss=0.173153
# [12/50]	eval_time=166.73 sec	current_logloss=0.176996	min_logloss=0.173153
# [13/50]	eval_time=96.51 sec	current_logloss=0.184308	min_logloss=0.173153
# [14/50]	eval_time=92.86 sec	current_logloss=0.173697	min_logloss=0.173153
# [15/50]	eval_time=197.52 sec	current_logloss=0.174832	min_logloss=0.173153
# [16/50]	eval_time=117.29 sec	current_logloss=0.174136	min_logloss=0.173153
# [17/50]	eval_time=183.75 sec	current_logloss=0.173431	min_logloss=0.173153
# [18/50]	eval_time=53.73 sec	current_logloss=0.175544	min_logloss=0.173153
# [19/50]	eval_time=55.79 sec	current_logloss=0.175954	min_logloss=0.173153
# [20/50]	eval_time=127.06 sec	current_logloss=0.180263	min_logloss=0.173153
# [21/50]	eval_time=64.32 sec	current_logloss=0.184139	min_logloss=0.173153
# [22/50]	eval_time=181.68 sec	current_logloss=0.172674	min_logloss=0.172674
# [23/50]	eval_time=189.50 sec	current_logloss=0.172734	min_logloss=0.172674
# [24/50]	eval_time=209.92 sec	current_logloss=0.172709	min_logloss=0.172674
# [25/50]	eval_time=207.03 sec	current_logloss=0.173382	min_logloss=0.172674
# [26/50]	eval_time=214.25 sec	current_logloss=0.173840	min_logloss=0.172674
# [27/50]	eval_time=78.90 sec	current_logloss=0.185167	min_logloss=0.172674
# [28/50]	eval_time=169.47 sec	current_logloss=0.172707	min_logloss=0.172674
# [29/50]	eval_time=175.79 sec	current_logloss=0.174830	min_logloss=0.172674
# [30/50]	eval_time=159.14 sec	current_logloss=0.172632	min_logloss=0.172632
# [31/50]	eval_time=136.53 sec	current_logloss=0.176710	min_logloss=0.172632
# [32/50]	eval_time=159.13 sec	current_logloss=0.174135	min_logloss=0.172632
# [33/50]	eval_time=169.65 sec	current_logloss=0.175326	min_logloss=0.172632
# [34/50]	eval_time=91.31 sec	current_logloss=0.193795	min_logloss=0.172632
# [35/50]	eval_time=159.80 sec	current_logloss=0.174710	min_logloss=0.172632
# [36/50]	eval_time=142.38 sec	current_logloss=0.174594	min_logloss=0.172632
# [37/50]	eval_time=60.50 sec	current_logloss=0.184261	min_logloss=0.172632
# [38/50]	eval_time=129.69 sec	current_logloss=0.173312	min_logloss=0.172632
# [39/50]	eval_time=153.41 sec	current_logloss=0.174445	min_logloss=0.172632
# [40/50]	eval_time=113.35 sec	current_logloss=0.174091	min_logloss=0.172632
# [41/50]	eval_time=164.36 sec	current_logloss=0.172957	min_logloss=0.172632
# [42/50]	eval_time=186.53 sec	current_logloss=0.175629	min_logloss=0.172632
# [43/50]	eval_time=202.67 sec	current_logloss=0.172198	min_logloss=0.172198
# [44/50]	eval_time=103.07 sec	current_logloss=0.178401	min_logloss=0.172198
# [45/50]	eval_time=156.15 sec	current_logloss=0.173799	min_logloss=0.172198
# [46/50]	eval_time=179.20 sec	current_logloss=0.174419	min_logloss=0.172198
# [47/50]	eval_time=148.25 sec	current_logloss=0.173918	min_logloss=0.172198
# [48/50]	eval_time=233.95 sec	current_logloss=0.174125	min_logloss=0.172198
# [49/50]	eval_time=148.93 sec	current_logloss=0.172786	min_logloss=0.172198
# [50/50]	eval_time=222.69 sec	current_logloss=0.175428	min_logloss=0.172198
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned XGBoost result on cv:
#
# logloss = 0.1721978
# best_n_estimators = 2938
# params = {'colsample_bytree': 0.7038509025904652, 'silent': 1, 'eval_metric': 'logloss', 'colsample_bylevel': 0.7837371393236529, 'min_child_weight': 9.904699292029688, 'subsample': 0.8154480009684183, 'eta': 0.002403852894964324, 'objective': 'binary:logistic', 'alpha': 0, 'seed': 0, 'max_depth': 10, 'gamma': 0, 'lambda': 0}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned XGBoost result on test:
#
# For seed=0 Test's logloss : 0.163313
# For seed=1 Test's logloss : 0.163374
# For seed=2 Test's logloss : 0.163321
# For seed=3 Test's logloss : 0.163080
# For seed=4 Test's logloss : 0.163266
#
# Test's logloss mean: 0.163271, Test's logloss std: 0.000101

# %% [markdown]
# ## `LightGBM`

# %%
lgb_default_test_result, lgb_tuned_test_result = run_experiment(LGBExperiment, "LightGBM")
# Out:
# Default LightGBM result on cv:
#
# logloss = 0.17267410548
# best_n_estimators = 48
# params = {'feature_fraction_seed': 0, 'num_leaves': 127, 'verbose': -1, 'bagging_seed': 0, 'lambda_l1': 0, 'drop_seed': 0, 'learning_rate': 0.1, 'lambda_l2': 0, 'data_random_seed': 0, 'bagging_fraction': 1.0, 'min_data_in_leaf': 100, 'max_bin': 255, 'objective': 'binary', 'bagging_freq': 1, 'metric': 'binary_logloss', 'min_sum_hessian_in_leaf': 10, 'feature_fraction': 1.0}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Default LightGBM result on test:
#
# For seed=0 Test's logloss : 0.167159
# For seed=1 Test's logloss : 0.167159
# For seed=2 Test's logloss : 0.167159
# For seed=3 Test's logloss : 0.167159
# For seed=4 Test's logloss : 0.167159
#
# Test's logloss mean: 0.167159, Test's logloss std: 0.000000
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Hyperopt iterations:
#
# [1/50]	eval_time=48.71 sec	current_logloss=0.172414	min_logloss=0.172414
# [2/50]	eval_time=14.25 sec	current_logloss=0.176051	min_logloss=0.172414
# [3/50]	eval_time=47.46 sec	current_logloss=0.171234	min_logloss=0.171234
# [4/50]	eval_time=13.35 sec	current_logloss=0.184258	min_logloss=0.171234
# [5/50]	eval_time=36.46 sec	current_logloss=0.179525	min_logloss=0.171234
# [6/50]	eval_time=409.52 sec	current_logloss=0.176632	min_logloss=0.171234
# [7/50]	eval_time=60.15 sec	current_logloss=0.171823	min_logloss=0.171234
# [8/50]	eval_time=15.87 sec	current_logloss=0.178681	min_logloss=0.171234
# [9/50]	eval_time=25.86 sec	current_logloss=0.176216	min_logloss=0.171234
# [10/50]	eval_time=44.66 sec	current_logloss=0.174232	min_logloss=0.171234
# [11/50]	eval_time=33.94 sec	current_logloss=0.171275	min_logloss=0.171234
# [12/50]	eval_time=37.61 sec	current_logloss=0.180358	min_logloss=0.171234
# [13/50]	eval_time=33.85 sec	current_logloss=0.189419	min_logloss=0.171234
# [14/50]	eval_time=16.06 sec	current_logloss=0.177782	min_logloss=0.171234
# [15/50]	eval_time=34.42 sec	current_logloss=0.173999	min_logloss=0.171234
# [16/50]	eval_time=24.00 sec	current_logloss=0.204192	min_logloss=0.171234
# [17/50]	eval_time=24.00 sec	current_logloss=0.184630	min_logloss=0.171234
# [18/50]	eval_time=194.38 sec	current_logloss=0.172683	min_logloss=0.171234
# [19/50]	eval_time=170.63 sec	current_logloss=0.180056	min_logloss=0.171234
# [20/50]	eval_time=39.95 sec	current_logloss=0.178553	min_logloss=0.171234
# [21/50]	eval_time=24.35 sec	current_logloss=0.171687	min_logloss=0.171234
# [22/50]	eval_time=27.10 sec	current_logloss=0.172344	min_logloss=0.171234
# [23/50]	eval_time=28.40 sec	current_logloss=0.176190	min_logloss=0.171234
# [24/50]	eval_time=19.03 sec	current_logloss=0.176361	min_logloss=0.171234
# [25/50]	eval_time=33.03 sec	current_logloss=0.172221	min_logloss=0.171234
# [26/50]	eval_time=17.95 sec	current_logloss=0.184273	min_logloss=0.171234
# [27/50]	eval_time=61.50 sec	current_logloss=0.173305	min_logloss=0.171234
# [28/50]	eval_time=34.23 sec	current_logloss=0.173902	min_logloss=0.171234
# [29/50]	eval_time=17.43 sec	current_logloss=0.174114	min_logloss=0.171234
# [30/50]	eval_time=68.41 sec	current_logloss=0.173676	min_logloss=0.171234
# [31/50]	eval_time=36.41 sec	current_logloss=0.171814	min_logloss=0.171234
# [32/50]	eval_time=38.23 sec	current_logloss=0.171726	min_logloss=0.171234
# [33/50]	eval_time=68.19 sec	current_logloss=0.174828	min_logloss=0.171234
# [34/50]	eval_time=13.53 sec	current_logloss=0.179836	min_logloss=0.171234
# [35/50]	eval_time=132.27 sec	current_logloss=0.173926	min_logloss=0.171234
# [36/50]	eval_time=48.13 sec	current_logloss=0.172037	min_logloss=0.171234
# [37/50]	eval_time=13.86 sec	current_logloss=0.190807	min_logloss=0.171234
# [38/50]	eval_time=1214.70 sec	current_logloss=0.183982	min_logloss=0.171234
# [39/50]	eval_time=15.19 sec	current_logloss=0.182430	min_logloss=0.171234
# [40/50]	eval_time=16.15 sec	current_logloss=0.173949	min_logloss=0.171234
# [41/50]	eval_time=18.85 sec	current_logloss=0.172890	min_logloss=0.171234
# [42/50]	eval_time=96.68 sec	current_logloss=0.174842	min_logloss=0.171234
# [43/50]	eval_time=13.68 sec	current_logloss=0.175600	min_logloss=0.171234
# [44/50]	eval_time=57.41 sec	current_logloss=0.172018	min_logloss=0.171234
# [45/50]	eval_time=29.34 sec	current_logloss=0.172230	min_logloss=0.171234
# [46/50]	eval_time=76.43 sec	current_logloss=0.171309	min_logloss=0.171234
# [47/50]	eval_time=159.04 sec	current_logloss=0.172938	min_logloss=0.171234
# [48/50]	eval_time=21.98 sec	current_logloss=0.175889	min_logloss=0.171234
# [49/50]	eval_time=39.47 sec	current_logloss=0.171325	min_logloss=0.171234
# [50/50]	eval_time=33.86 sec	current_logloss=0.173312	min_logloss=0.171234
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned LightGBM result on cv:
#
# logloss = 0.171233507061
# best_n_estimators = 3195
# params = {'num_leaves': 35, 'verbose': -1, 'bagging_seed': 0, 'metric': 'binary_logloss', 'data_random_seed': 0, 'min_data_in_leaf': 43, 'bagging_fraction': 0.7533430554699614, 'min_sum_hessian_in_leaf': 3.7668542981896906e-07, 'feature_fraction_seed': 0, 'lambda_l1': 0, 'bagging_freq': 1, 'lambda_l2': 0, 'objective': 'binary', 'drop_seed': 0, 'learning_rate': 0.0023062503242047053, 'feature_fraction': 0.8942720034091154}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned LightGBM result on test:
#
# For seed=0 Test's logloss : 0.163443
# For seed=1 Test's logloss : 0.163637
# For seed=2 Test's logloss : 0.163410
# For seed=3 Test's logloss : 0.163710
# For seed=4 Test's logloss : 0.163799
#
# Test's logloss mean: 0.163600, Test's logloss std: 0.000151

# %% [markdown]
# ## `CatBoost`

# %%
cab_default_test_result, cab_tuned_test_result = run_experiment(CABExperiment, "CatBoost")
# Out:
# Default CatBoost result on cv:
#
# logloss = 0.13852654112
# best_n_estimators = 1007
# params = {'rsm': 1.0, 'iterations': 1007, 'random_seed': 4, 'verbose': False, 'thread_count': 16, 'learning_rate': 0.03, 'ctr_description': ['Borders', 'CounterMax'], 'depth': 6, 'fold_len_multiplier': 2, 'loss_function': 'Logloss', 'ctr_border_count': 16, 'l2_leaf_reg': 3, 'leaf_estimation_method': 'Newton', 'gradient_iterations': 10, 'border_count': 128, 'used_ram_limit': 100000000000}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Default CatBoost result on test:
#
# For seed=0 Test's logloss : 0.138380
# For seed=1 Test's logloss : 0.137411
# For seed=2 Test's logloss : 0.138474
# For seed=3 Test's logloss : 0.138047
# For seed=4 Test's logloss : 0.138257
#
# Test's logloss mean: 0.138114, Test's logloss std: 0.000379
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Hyperopt iterations:
#
# [1/50]	eval_time=626.58 sec	current_logloss=0.138781	min_logloss=0.138781
# [2/50]	eval_time=622.89 sec	current_logloss=0.141316	min_logloss=0.138781
# [3/50]	eval_time=572.45 sec	current_logloss=0.140226	min_logloss=0.138781
# [4/50]	eval_time=607.57 sec	current_logloss=0.138747	min_logloss=0.138747
# [5/50]	eval_time=726.78 sec	current_logloss=0.138342	min_logloss=0.138342
# [6/50]	eval_time=616.75 sec	current_logloss=0.138508	min_logloss=0.138342
# [7/50]	eval_time=603.50 sec	current_logloss=0.139239	min_logloss=0.138342
# [8/50]	eval_time=749.05 sec	current_logloss=0.138532	min_logloss=0.138342
# [9/50]	eval_time=617.38 sec	current_logloss=0.145741	min_logloss=0.138342
# [10/50]	eval_time=747.57 sec	current_logloss=0.139593	min_logloss=0.138342
# [11/50]	eval_time=593.61 sec	current_logloss=0.138565	min_logloss=0.138342
# [12/50]	eval_time=607.90 sec	current_logloss=0.139182	min_logloss=0.138342
# [13/50]	eval_time=611.39 sec	current_logloss=0.138970	min_logloss=0.138342
# [14/50]	eval_time=735.03 sec	current_logloss=0.138618	min_logloss=0.138342
# [15/50]	eval_time=625.94 sec	current_logloss=0.138976	min_logloss=0.138342
# [16/50]	eval_time=763.95 sec	current_logloss=0.141875	min_logloss=0.138342
# [17/50]	eval_time=760.88 sec	current_logloss=0.141696	min_logloss=0.138342
# [18/50]	eval_time=610.20 sec	current_logloss=0.138634	min_logloss=0.138342
# [19/50]	eval_time=616.13 sec	current_logloss=0.139230	min_logloss=0.138342
# [20/50]	eval_time=761.49 sec	current_logloss=0.139495	min_logloss=0.138342
# [21/50]	eval_time=758.23 sec	current_logloss=0.138663	min_logloss=0.138342
# [22/50]	eval_time=754.26 sec	current_logloss=0.138308	min_logloss=0.138308
# [23/50]	eval_time=756.08 sec	current_logloss=0.138271	min_logloss=0.138271
# [24/50]	eval_time=753.89 sec	current_logloss=0.138290	min_logloss=0.138271
# [25/50]	eval_time=756.99 sec	current_logloss=0.138363	min_logloss=0.138271
# [26/50]	eval_time=762.67 sec	current_logloss=0.140741	min_logloss=0.138271
# [27/50]	eval_time=763.18 sec	current_logloss=0.150082	min_logloss=0.138271
# [28/50]	eval_time=759.17 sec	current_logloss=0.138659	min_logloss=0.138271
# [29/50]	eval_time=762.52 sec	current_logloss=0.139181	min_logloss=0.138271
# [30/50]	eval_time=758.16 sec	current_logloss=0.138790	min_logloss=0.138271
# [31/50]	eval_time=763.33 sec	current_logloss=0.146243	min_logloss=0.138271
# [32/50]	eval_time=751.32 sec	current_logloss=0.138505	min_logloss=0.138271
# [33/50]	eval_time=767.07 sec	current_logloss=0.144365	min_logloss=0.138271
# [34/50]	eval_time=746.88 sec	current_logloss=0.139888	min_logloss=0.138271
# [35/50]	eval_time=758.87 sec	current_logloss=0.138311	min_logloss=0.138271
# [36/50]	eval_time=760.78 sec	current_logloss=0.139690	min_logloss=0.138271
# [37/50]	eval_time=756.41 sec	current_logloss=0.138359	min_logloss=0.138271
# [38/50]	eval_time=752.13 sec	current_logloss=0.138748	min_logloss=0.138271
# [39/50]	eval_time=753.87 sec	current_logloss=0.138399	min_logloss=0.138271
# [40/50]	eval_time=754.33 sec	current_logloss=0.139260	min_logloss=0.138271
# [41/50]	eval_time=761.25 sec	current_logloss=0.139266	min_logloss=0.138271
# [42/50]	eval_time=749.47 sec	current_logloss=0.139524	min_logloss=0.138271
# [43/50]	eval_time=601.47 sec	current_logloss=0.139431	min_logloss=0.138271
# [44/50]	eval_time=719.71 sec	current_logloss=0.138635	min_logloss=0.138271
# [45/50]	eval_time=622.13 sec	current_logloss=0.138577	min_logloss=0.138271
# [46/50]	eval_time=736.84 sec	current_logloss=0.138526	min_logloss=0.138271
# [47/50]	eval_time=613.17 sec	current_logloss=0.138772	min_logloss=0.138271
# [48/50]	eval_time=764.89 sec	current_logloss=0.143430	min_logloss=0.138271
# [49/50]	eval_time=759.35 sec	current_logloss=0.139079	min_logloss=0.138271
# [50/50]	eval_time=623.57 sec	current_logloss=0.140285	min_logloss=0.138271
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned CatBoost result on cv:
#
# logloss = 0.13827066104
# best_n_estimators = 3924
# params = {'random_seed': 4, 'verbose': False, 'thread_count': 16, 'learning_rate': 0.007817097085078113, 'ctr_border_count': 16, 'ctr_description': ('Borders', 'CounterMax'), 'iterations': 3924, 'one_hot_max_size': 0, 'bagging_temperature': 0.9974813111708178, 'gradient_iterations': 10, 'random_strength': 1, 'depth': 6, 'loss_function': 'Logloss', 'l2_leaf_reg': 2.8488998726594352, 'border_count': 128, 'used_ram_limit': 100000000000}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned CatBoost result on test:
#
# For seed=0 Test's logloss : 0.138023
# For seed=1 Test's logloss : 0.137645
# For seed=2 Test's logloss : 0.137974
# For seed=3 Test's logloss : 0.136742
# For seed=4 Test's logloss : 0.138218
#
# Test's logloss mean: 0.137720, Test's logloss std: 0.000523

# %% [markdown]
# ## Comparing results
#
# The final table with metric values on the test dataset.

# %%
import pandas as pd
import numpy as np
from IPython.display import HTML, display
# %pylab inline --no-import-all

test_results = np.array([
    (xgb_default_test_result, xgb_tuned_test_result),
    (lgb_default_test_result, lgb_tuned_test_result),
    (cab_default_test_result, cab_tuned_test_result)
])

diff = 100 * test_results / test_results[2,1] - 100

res = [['{:.6f} ({:+.2f}%)'.format(test_results[i, j], diff[i, j]) for j in range(2)] for i in range(3)]

display(HTML(pd.DataFrame(res, columns=['default', 'tuned'], index=['xgboost', 'lightgbm', 'catboost']).to_html()))

results = [
    ('Tuned CatBoost',   cab_tuned_test_result),
    ('Default CatBoost', cab_default_test_result),
    ('Tuned XGBoost',    xgb_tuned_test_result),
    ('Default XGBoost',  xgb_default_test_result),
    ('Tuned LightGBM',   lgb_tuned_test_result),
    ('Default LightGBM', lgb_default_test_result),
]
names = ['%s\n%.5f' % (name, loss) for name, loss in results]

plt.figure(figsize=(20, 7))
plt.scatter(range(6), zip(*results)[1], s=150)
plt.xticks(range(6), names, fontsize=15)
plt.yticks(fontsize=12)
plt.title('Comparison', fontsize=20)
plt.ylabel(experiment.metric, fontsize=16);
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>default</th>
#       <th>tuned</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>xgboost</th>
#       <td>0.165365 (+20.07%)</td>
#       <td>0.163271 (+18.55%)</td>
#     </tr>
#     <tr>
#       <th>lightgbm</th>
#       <td>0.167159 (+21.38%)</td>
#       <td>0.163600 (+18.79%)</td>
#     </tr>
#     <tr>
#       <th>catboost</th>
#       <td>0.138114 (+0.29%)</td>
#       <td>0.137720 (+0.00%)</td>
#     </tr>
#   </tbody>
# </table>
