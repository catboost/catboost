# %% [markdown]
# # Comparing algorithms on the Kick dataset
# The data is taken from [this source](https://www.kaggle.com/c/DontGetKicked).

# %% [markdown]
# For details on running the comparison, see [this article](https://github.com/catboost/benchmarks/blob/master/comparison_description.pdf).

# %%
from experiment import Experiment
from xgboost_experiment import XGBExperiment
from lightgbm_experiment import LGBExperiment
from catboost_experiment import CABExperiment

# %% [markdown]
# Load the dataset and set parameters for the experiment.

# %%
learning_task = 'classification'
dataset_path = '/media/pool_storage/tsnet-pools-converted/kick/'
n_estimators = 5000
max_hyperopt_evals = 50

experiment = Experiment(learning_task, train_path=dataset_path + 'train_full3',
                        test_path=dataset_path + 'test3', cd_path = dataset_path + 'train_full3.cd')
X_train, y_train, X_test, y_test, cat_cols = experiment.read_data()

# %% [markdown]
# Write a function that does the following:
#
# **Preprocess the dataset:**
# calculate counter values on the training set, transform cat features (for the `XGBoost` and `LightGBM` algorithms), and convert the data to the format of the algorithm. Do the same thing with all pairs after splitting them into cross validation folds.
#
# **Select the optimal number of trees for the algorithm with the default parameters:** for each fold and each number of trees, get the result of the algorithm trained on the other four folds, average the results for each number of trees, and choose the best one.
#
# **Assess the quality of the algorithm with the default parameters on a test dataset:** train the algorithm with the number of trees obtained in the previous step, and calculate the metric value on the test dataset.
#
# **Tune parameters for the algorithm using `Hyperopt`:** on each `Hyperopt` iteration of the algorithm, the best value of trees is selected and the metric for cross validation is calculated.
#
# **Show results on the test dataset for the algorithm with the tuned parameters:** train the algorithm with the optimal parameters and the number of trees obtained in the previous step, and calculate the metric value on the test dataset.

# %%
import numpy as np

def run_experiment(Experiment, title):
    experiment = Experiment(learning_task, max_hyperopt_evals=max_hyperopt_evals,
                            n_estimators=n_estimators)
    cv_pairs, (dtrain, dtest) = experiment.split_and_preprocess(X_train.copy(), y_train, 
                                                                X_test.copy(), y_test, 
                                                                cat_cols, n_splits=5)
 
    default_cv_result = experiment.run_cv(cv_pairs)
    experiment.print_result(default_cv_result, 'Default {} result on cv'.format(title))

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')

    default_test_losses = []
    for seed in range(5):
        test_result = experiment.run_test(dtrain, dtest, X_test, params=default_cv_result['params'],
                                          n_estimators=default_cv_result['best_n_estimators'], seed=seed)
        default_test_losses.append(test_result['loss'])
        print 'For seed=%d Test\'s %s : %.5f' % (seed, experiment.metric, default_test_losses[-1])
    print '\nTest\'s %s mean: %.5f, Test\'s %s std: %.5f' % (experiment.metric, np.mean(default_test_losses),
                                                             experiment.metric, np.std(default_test_losses))

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')
    print('Hyperopt iterations:\n\n')

    tuned_cv_result = experiment.optimize_params(cv_pairs)

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')

    experiment.print_result(tuned_cv_result, 'Tuned {} result on cv'.format(title))

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')

    tuned_test_losses = []
    for seed in range(5):
        test_result = experiment.run_test(dtrain, dtest, X_test, params=tuned_cv_result['params'],
                                          n_estimators=tuned_cv_result['best_n_estimators'], seed=seed)
        tuned_test_losses.append(test_result['loss'])
        print 'For seed=%d Test\'s %s : %.5f' % (seed, experiment.metric, tuned_test_losses[-1])
    print '\nTest\'s %s mean: %.5f, Test\'s %s std: %.5f' % (experiment.metric, np.mean(tuned_test_losses),
                                                             experiment.metric, np.std(tuned_test_losses))

    return np.mean(default_test_losses), np.mean(tuned_test_losses)

# %% [markdown]
# ## `XGBoost`

# %%
xgb_default_test_result, xgb_tuned_test_result = run_experiment(XGBExperiment, "XGBoost")
# Out:
# Default XGBoost result on cv:
#
# logloss = 0.2980504
# best_n_estimators = 16
# params = {'colsample_bytree': 1.0, 'silent': 1, 'eval_metric': 'logloss', 'colsample_bylevel': 1.0, 'min_child_weight': 1, 'subsample': 1.0, 'eta': 0.3, 'objective': 'binary:logistic', 'alpha': 0, 'seed': 0, 'max_depth': 6, 'gamma': 0, 'lambda': 1}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Default XGBoost result on test:
#
# For seed=0 Test's logloss : 0.298161
# For seed=1 Test's logloss : 0.298161
# For seed=2 Test's logloss : 0.298161
# For seed=3 Test's logloss : 0.298161
# For seed=4 Test's logloss : 0.298161
#
# Test's logloss mean: 0.298161, Test's logloss std: 0.000000
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Hyperopt iterations:
#
# [1/50]	eval_time=427.56 sec	current_logloss=0.296300	min_logloss=0.296300
# [2/50]	eval_time=494.98 sec	current_logloss=0.295495	min_logloss=0.295495
# [3/50]	eval_time=377.45 sec	current_logloss=0.301028	min_logloss=0.295495
# [4/50]	eval_time=213.58 sec	current_logloss=0.297586	min_logloss=0.295495
# [5/50]	eval_time=254.46 sec	current_logloss=0.299428	min_logloss=0.295495
# [6/50]	eval_time=356.94 sec	current_logloss=0.297574	min_logloss=0.295495
# [7/50]	eval_time=401.20 sec	current_logloss=0.310739	min_logloss=0.295495
# [8/50]	eval_time=462.59 sec	current_logloss=0.295815	min_logloss=0.295495
# [9/50]	eval_time=348.34 sec	current_logloss=0.297863	min_logloss=0.295495
# [10/50]	eval_time=946.48 sec	current_logloss=0.294890	min_logloss=0.294890
# [11/50]	eval_time=204.40 sec	current_logloss=0.299566	min_logloss=0.294890
# [12/50]	eval_time=867.04 sec	current_logloss=0.297223	min_logloss=0.294890
# [13/50]	eval_time=300.18 sec	current_logloss=0.302017	min_logloss=0.294890
# [14/50]	eval_time=314.72 sec	current_logloss=0.296484	min_logloss=0.294890
# [15/50]	eval_time=776.15 sec	current_logloss=0.295643	min_logloss=0.294890
# [16/50]	eval_time=405.62 sec	current_logloss=0.296338	min_logloss=0.294890
# [17/50]	eval_time=585.30 sec	current_logloss=0.295193	min_logloss=0.294890
# [18/50]	eval_time=170.15 sec	current_logloss=0.298816	min_logloss=0.294890
# [19/50]	eval_time=203.18 sec	current_logloss=0.299826	min_logloss=0.294890
# [20/50]	eval_time=459.84 sec	current_logloss=0.299538	min_logloss=0.294890
# [21/50]	eval_time=518.85 sec	current_logloss=0.299004	min_logloss=0.294890
# [22/50]	eval_time=703.79 sec	current_logloss=0.295323	min_logloss=0.294890
# [23/50]	eval_time=538.20 sec	current_logloss=0.295551	min_logloss=0.294890
# [24/50]	eval_time=479.62 sec	current_logloss=0.298579	min_logloss=0.294890
# [25/50]	eval_time=769.63 sec	current_logloss=0.294635	min_logloss=0.294635
# [26/50]	eval_time=695.33 sec	current_logloss=0.294804	min_logloss=0.294635
# [27/50]	eval_time=688.17 sec	current_logloss=0.294843	min_logloss=0.294635
# [28/50]	eval_time=691.24 sec	current_logloss=0.294891	min_logloss=0.294635
# [29/50]	eval_time=958.87 sec	current_logloss=0.294894	min_logloss=0.294635
# [30/50]	eval_time=467.24 sec	current_logloss=0.317133	min_logloss=0.294635
# [31/50]	eval_time=542.92 sec	current_logloss=0.296342	min_logloss=0.294635
# [32/50]	eval_time=936.23 sec	current_logloss=0.295502	min_logloss=0.294635
# [33/50]	eval_time=776.14 sec	current_logloss=0.311792	min_logloss=0.294635
# [34/50]	eval_time=637.49 sec	current_logloss=0.294713	min_logloss=0.294635
# [35/50]	eval_time=535.56 sec	current_logloss=0.295103	min_logloss=0.294635
# [36/50]	eval_time=466.11 sec	current_logloss=0.295345	min_logloss=0.294635
# [37/50]	eval_time=419.31 sec	current_logloss=0.296312	min_logloss=0.294635
# [38/50]	eval_time=622.01 sec	current_logloss=0.295449	min_logloss=0.294635
# [39/50]	eval_time=689.03 sec	current_logloss=0.294676	min_logloss=0.294635
# [40/50]	eval_time=736.48 sec	current_logloss=0.294678	min_logloss=0.294635
# [41/50]	eval_time=1078.57 sec	current_logloss=0.294973	min_logloss=0.294635
# [42/50]	eval_time=495.33 sec	current_logloss=0.296696	min_logloss=0.294635
# [43/50]	eval_time=582.14 sec	current_logloss=0.295631	min_logloss=0.294635
# [44/50]	eval_time=683.33 sec	current_logloss=0.295096	min_logloss=0.294635
# [45/50]	eval_time=745.83 sec	current_logloss=0.296302	min_logloss=0.294635
# [46/50]	eval_time=1163.56 sec	current_logloss=0.295149	min_logloss=0.294635
# [47/50]	eval_time=733.17 sec	current_logloss=0.295026	min_logloss=0.294635
# [48/50]	eval_time=392.41 sec	current_logloss=0.295741	min_logloss=0.294635
# [49/50]	eval_time=715.87 sec	current_logloss=0.294648	min_logloss=0.294635
# [50/50]	eval_time=728.61 sec	current_logloss=0.294803	min_logloss=0.294635
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned XGBoost result on cv:
#
# logloss = 0.2946354
# best_n_estimators = 4927
# params = {'colsample_bytree': 0.8504571925671729, 'silent': 1, 'eval_metric': 'logloss', 'colsample_bylevel': 0.7701696088367048, 'min_child_weight': 0.0006883106940449714, 'subsample': 0.79765085835875, 'eta': 0.0010592266135891414, 'objective': 'binary:logistic', 'alpha': 0, 'seed': 0, 'max_depth': 9, 'gamma': 1.4749747301991976e-07, 'lambda': 0.0005896408800930098}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned XGBoost result on test:
#
# For seed=0 Test's logloss : 0.294710
# For seed=1 Test's logloss : 0.294662
# For seed=2 Test's logloss : 0.294629
# For seed=3 Test's logloss : 0.294663
# For seed=4 Test's logloss : 0.294573
#
# Test's logloss mean: 0.294647, Test's logloss std: 0.000045

# %% [markdown]
# ## `LightGBM`

# %%
lgb_default_test_result, lgb_tuned_test_result = run_experiment(LGBExperiment, "LightGBM")
# Out:
# Default LightGBM result on cv:
#
# logloss = 0.299201893697
# best_n_estimators = 51
# params = {'feature_fraction_seed': 0, 'num_leaves': 127, 'verbose': -1, 'bagging_seed': 0, 'lambda_l1': 0, 'drop_seed': 0, 'learning_rate': 0.1, 'lambda_l2': 0, 'data_random_seed': 0, 'bagging_fraction': 1.0, 'min_data_in_leaf': 100, 'max_bin': 255, 'objective': 'binary', 'bagging_freq': 1, 'metric': 'binary_logloss', 'min_sum_hessian_in_leaf': 10, 'feature_fraction': 1.0}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Default LightGBM result on test:
#
# For seed=0 Test's logloss : 0.298774
# For seed=1 Test's logloss : 0.298774
# For seed=2 Test's logloss : 0.298774
# For seed=3 Test's logloss : 0.298774
# For seed=4 Test's logloss : 0.298774
#
# Test's logloss mean: 0.298774, Test's logloss std: 0.000000
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Hyperopt iterations:
#
# [1/50]	eval_time=174.09 sec	current_logloss=0.297507	min_logloss=0.297507
# [2/50]	eval_time=31.72 sec	current_logloss=0.305129	min_logloss=0.297507
# [3/50]	eval_time=92.04 sec	current_logloss=0.295824	min_logloss=0.295824
# [4/50]	eval_time=28.68 sec	current_logloss=0.309871	min_logloss=0.295824
# [5/50]	eval_time=102.34 sec	current_logloss=0.300859	min_logloss=0.295824
# [6/50]	eval_time=792.01 sec	current_logloss=0.296890	min_logloss=0.295824
# [7/50]	eval_time=129.89 sec	current_logloss=0.296411	min_logloss=0.295824
# [8/50]	eval_time=32.60 sec	current_logloss=0.303313	min_logloss=0.295824
# [9/50]	eval_time=85.03 sec	current_logloss=0.299393	min_logloss=0.295824
# [10/50]	eval_time=116.40 sec	current_logloss=0.303259	min_logloss=0.295824
# [11/50]	eval_time=74.15 sec	current_logloss=0.296206	min_logloss=0.295824
# [12/50]	eval_time=131.57 sec	current_logloss=0.313369	min_logloss=0.295824
# [13/50]	eval_time=90.76 sec	current_logloss=0.307871	min_logloss=0.295824
# [14/50]	eval_time=35.29 sec	current_logloss=0.302590	min_logloss=0.295824
# [15/50]	eval_time=82.05 sec	current_logloss=0.301629	min_logloss=0.295824
# [16/50]	eval_time=55.10 sec	current_logloss=0.339739	min_logloss=0.295824
# [17/50]	eval_time=54.88 sec	current_logloss=0.307078	min_logloss=0.295824
# [18/50]	eval_time=396.64 sec	current_logloss=0.296481	min_logloss=0.295824
# [19/50]	eval_time=571.51 sec	current_logloss=0.298498	min_logloss=0.295824
# [20/50]	eval_time=154.98 sec	current_logloss=0.311300	min_logloss=0.295824
# [21/50]	eval_time=52.47 sec	current_logloss=0.296109	min_logloss=0.295824
# [22/50]	eval_time=51.29 sec	current_logloss=0.296382	min_logloss=0.295824
# [23/50]	eval_time=56.98 sec	current_logloss=0.296439	min_logloss=0.295824
# [24/50]	eval_time=45.75 sec	current_logloss=0.297289	min_logloss=0.295824
# [25/50]	eval_time=52.62 sec	current_logloss=0.302254	min_logloss=0.295824
# [26/50]	eval_time=64.72 sec	current_logloss=0.296082	min_logloss=0.295824
# [27/50]	eval_time=69.03 sec	current_logloss=0.296526	min_logloss=0.295824
# [28/50]	eval_time=115.90 sec	current_logloss=0.297801	min_logloss=0.295824
# [29/50]	eval_time=162.67 sec	current_logloss=0.296726	min_logloss=0.295824
# [30/50]	eval_time=40.40 sec	current_logloss=0.297273	min_logloss=0.295824
# [31/50]	eval_time=34.32 sec	current_logloss=0.305105	min_logloss=0.295824
# [32/50]	eval_time=84.51 sec	current_logloss=0.297116	min_logloss=0.295824
# [33/50]	eval_time=67.60 sec	current_logloss=0.295705	min_logloss=0.295705
# [34/50]	eval_time=32.81 sec	current_logloss=0.307276	min_logloss=0.295705
# [35/50]	eval_time=1638.01 sec	current_logloss=0.298687	min_logloss=0.295705
# [36/50]	eval_time=135.63 sec	current_logloss=0.296913	min_logloss=0.295705
# [37/50]	eval_time=39.22 sec	current_logloss=0.297530	min_logloss=0.295705
# [38/50]	eval_time=30.48 sec	current_logloss=0.312662	min_logloss=0.295705
# [39/50]	eval_time=214.42 sec	current_logloss=0.296214	min_logloss=0.295705
# [40/50]	eval_time=93.36 sec	current_logloss=0.296036	min_logloss=0.295705
# [41/50]	eval_time=79.65 sec	current_logloss=0.297170	min_logloss=0.295705
# [42/50]	eval_time=66.25 sec	current_logloss=0.296756	min_logloss=0.295705
# [43/50]	eval_time=141.45 sec	current_logloss=0.297024	min_logloss=0.295705
# [44/50]	eval_time=489.85 sec	current_logloss=0.298164	min_logloss=0.295705
# [45/50]	eval_time=42.56 sec	current_logloss=0.298165	min_logloss=0.295705
# [46/50]	eval_time=101.22 sec	current_logloss=0.295985	min_logloss=0.295705
# [47/50]	eval_time=295.66 sec	current_logloss=0.295591	min_logloss=0.295591
# [48/50]	eval_time=275.75 sec	current_logloss=0.296535	min_logloss=0.295591
# [49/50]	eval_time=512.28 sec	current_logloss=0.296767	min_logloss=0.295591
# [50/50]	eval_time=1899.94 sec	current_logloss=0.302871	min_logloss=0.295591
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned LightGBM result on cv:
#
# logloss = 0.29559084625
# best_n_estimators = 3004
# params = {'num_leaves': 157, 'verbose': -1, 'bagging_seed': 0, 'metric': 'binary_logloss', 'data_random_seed': 0, 'min_data_in_leaf': 4, 'bagging_fraction': 0.7618075391294016, 'min_sum_hessian_in_leaf': 3.776016815653153e-06, 'feature_fraction_seed': 0, 'lambda_l1': 0, 'bagging_freq': 1, 'lambda_l2': 0.07371594809127686, 'objective': 'binary', 'drop_seed': 0, 'learning_rate': 0.0019483006590789694, 'feature_fraction': 0.7515374545303946}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned LightGBM result on test:
#
# For seed=0 Test's logloss : 0.295582
# For seed=1 Test's logloss : 0.295669
# For seed=2 Test's logloss : 0.295649
# For seed=3 Test's logloss : 0.295710
# For seed=4 Test's logloss : 0.295691
#
# Test's logloss mean: 0.295660, Test's logloss std: 0.000044

# %% [markdown]
# ## `CatBoost`

# %%
cab_default_test_result, cab_tuned_test_result = run_experiment(CABExperiment, "CatBoost")
# Out:
# Default CatBoost result on cv:
#
# logloss = 0.28533209332
# best_n_estimators = 2422
# params = {'rsm': 1.0, 'iterations': 2422, 'random_seed': 4, 'verbose': False, 'thread_count': 16, 'learning_rate': 0.03, 'ctr_description': ['Borders', 'CounterMax'], 'depth': 6, 'fold_len_multiplier': 2, 'loss_function': 'Logloss', 'ctr_border_count': 16, 'l2_leaf_reg': 3, 'leaf_estimation_method': 'Newton', 'gradient_iterations': 10, 'border_count': 128, 'used_ram_limit': 100000000000}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Default CatBoost result on test:
#
# For seed=0 Test's logloss : 0.285041
# For seed=1 Test's logloss : 0.284506
# For seed=2 Test's logloss : 0.284702
# For seed=3 Test's logloss : 0.284928
# For seed=4 Test's logloss : 0.285384
#
# Test's logloss mean: 0.284912, Test's logloss std: 0.000300
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Hyperopt iterations:
#
# [1/50]	eval_time=1010.40 sec	current_logloss=0.286286	min_logloss=0.286286
# [2/50]	eval_time=1703.25 sec	current_logloss=0.287849	min_logloss=0.286286
# [3/50]	eval_time=922.70 sec	current_logloss=0.287660	min_logloss=0.286286
# [4/50]	eval_time=979.26 sec	current_logloss=0.286282	min_logloss=0.286282
# [5/50]	eval_time=1754.51 sec	current_logloss=0.286414	min_logloss=0.286282
# [6/50]	eval_time=992.42 sec	current_logloss=0.286179	min_logloss=0.286179
# [7/50]	eval_time=989.95 sec	current_logloss=0.286587	min_logloss=0.286179
# [8/50]	eval_time=1184.38 sec	current_logloss=0.286782	min_logloss=0.286179
# [9/50]	eval_time=1703.56 sec	current_logloss=0.292888	min_logloss=0.286179
# [10/50]	eval_time=1884.92 sec	current_logloss=0.285574	min_logloss=0.285574
# [11/50]	eval_time=1619.21 sec	current_logloss=0.285463	min_logloss=0.285463
# [12/50]	eval_time=1705.26 sec	current_logloss=0.285579	min_logloss=0.285463
# [13/50]	eval_time=1008.18 sec	current_logloss=0.286419	min_logloss=0.285463
# [14/50]	eval_time=1167.36 sec	current_logloss=0.286322	min_logloss=0.285463
# [15/50]	eval_time=1713.25 sec	current_logloss=0.285723	min_logloss=0.285463
# [16/50]	eval_time=1207.54 sec	current_logloss=0.289702	min_logloss=0.285463
# [17/50]	eval_time=1918.80 sec	current_logloss=0.288031	min_logloss=0.285463
# [18/50]	eval_time=1697.30 sec	current_logloss=0.285161	min_logloss=0.285161
# [19/50]	eval_time=1001.48 sec	current_logloss=0.287348	min_logloss=0.285161
# [20/50]	eval_time=1197.85 sec	current_logloss=0.287699	min_logloss=0.285161
# [21/50]	eval_time=1681.67 sec	current_logloss=0.285415	min_logloss=0.285161
# [22/50]	eval_time=1627.77 sec	current_logloss=0.286755	min_logloss=0.285161
# [23/50]	eval_time=1698.56 sec	current_logloss=0.285257	min_logloss=0.285161
# [24/50]	eval_time=1700.82 sec	current_logloss=0.285269	min_logloss=0.285161
# [25/50]	eval_time=1707.64 sec	current_logloss=0.286186	min_logloss=0.285161
# [26/50]	eval_time=1721.29 sec	current_logloss=0.285392	min_logloss=0.285161
# [27/50]	eval_time=1633.97 sec	current_logloss=0.286934	min_logloss=0.285161
# [28/50]	eval_time=1710.04 sec	current_logloss=0.291961	min_logloss=0.285161
# [29/50]	eval_time=1725.58 sec	current_logloss=0.285023	min_logloss=0.285023
# [30/50]	eval_time=1730.18 sec	current_logloss=0.285011	min_logloss=0.285011
# [31/50]	eval_time=1725.00 sec	current_logloss=0.285266	min_logloss=0.285011
# [32/50]	eval_time=1718.48 sec	current_logloss=0.286170	min_logloss=0.285011
# [33/50]	eval_time=1707.58 sec	current_logloss=0.287669	min_logloss=0.285011
# [34/50]	eval_time=1722.63 sec	current_logloss=0.285471	min_logloss=0.285011
# [35/50]	eval_time=1729.49 sec	current_logloss=0.285049	min_logloss=0.285011
# [36/50]	eval_time=1907.74 sec	current_logloss=0.286251	min_logloss=0.285011
# [37/50]	eval_time=1712.85 sec	current_logloss=0.286187	min_logloss=0.285011
# [38/50]	eval_time=1728.27 sec	current_logloss=0.284972	min_logloss=0.284972
# [39/50]	eval_time=1910.50 sec	current_logloss=0.285256	min_logloss=0.284972
# [40/50]	eval_time=1012.22 sec	current_logloss=0.291187	min_logloss=0.284972
# [41/50]	eval_time=1724.63 sec	current_logloss=0.284940	min_logloss=0.284940
# [42/50]	eval_time=1691.72 sec	current_logloss=0.285073	min_logloss=0.284940
# [43/50]	eval_time=1182.01 sec	current_logloss=0.286333	min_logloss=0.284940
# [44/50]	eval_time=1701.45 sec	current_logloss=0.285488	min_logloss=0.284940
# [45/50]	eval_time=1723.20 sec	current_logloss=0.285088	min_logloss=0.284940
# [46/50]	eval_time=1190.85 sec	current_logloss=0.286406	min_logloss=0.284940
# [47/50]	eval_time=1716.67 sec	current_logloss=0.285108	min_logloss=0.284940
# [48/50]	eval_time=1706.17 sec	current_logloss=0.286899	min_logloss=0.284940
# [49/50]	eval_time=1153.57 sec	current_logloss=0.286237	min_logloss=0.284940
# [50/50]	eval_time=1722.41 sec	current_logloss=0.285057	min_logloss=0.284940
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned CatBoost result on cv:
#
# logloss = 0.284939952
# best_n_estimators = 3105
# params = {'random_seed': 4, 'verbose': False, 'thread_count': 16, 'learning_rate': 0.032315414052930716, 'ctr_border_count': 16, 'ctr_description': ('Borders', 'CounterMax'), 'iterations': 3105, 'one_hot_max_size': 0, 'bagging_temperature': 0.7689899608007091, 'gradient_iterations': 1, 'random_strength': 1, 'depth': 6, 'loss_function': 'Logloss', 'l2_leaf_reg': 6.419384882472304, 'border_count': 128, 'used_ram_limit': 100000000000}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned CatBoost result on test:
#
# For seed=0 Test's logloss : 0.284505
# For seed=1 Test's logloss : 0.285111
# For seed=2 Test's logloss : 0.284863
# For seed=3 Test's logloss : 0.284948
# For seed=4 Test's logloss : 0.284540
#
# Test's logloss mean: 0.284793, Test's logloss std: 0.000235

# %% [markdown]
# ## Comparing results
#
# The final table with metric values on the test dataset.

# %%
import pandas as pd
import numpy as np
from IPython.display import HTML, display
# %pylab inline --no-import-all

test_results = np.array([
    (xgb_default_test_result, xgb_tuned_test_result),
    (lgb_default_test_result, lgb_tuned_test_result),
    (cab_default_test_result, cab_tuned_test_result)
])

diff = 100 * test_results / test_results[2,1] - 100

res = [['{:.6f} ({:+.2f}%)'.format(test_results[i, j], diff[i, j]) for j in range(2)] for i in range(3)]

display(HTML(pd.DataFrame(res, columns=['default', 'tuned'], index=['xgboost', 'lightgbm', 'catboost']).to_html()))

results = [
    ('Tuned CatBoost',   cab_tuned_test_result),
    ('Default CatBoost', cab_default_test_result),
    ('Tuned XGBoost',    xgb_tuned_test_result),
    ('Default XGBoost',  xgb_default_test_result),
    ('Tuned LightGBM',   lgb_tuned_test_result),
    ('Default LightGBM', lgb_default_test_result),
]
names = ['%s\n%.5f' % (name, loss) for name, loss in results]

plt.figure(figsize=(20, 7))
plt.scatter(range(6), zip(*results)[1], s=150)
plt.xticks(range(6), names, fontsize=15)
plt.yticks(fontsize=12)
plt.title('Comparison', fontsize=20)
plt.ylabel(experiment.metric, fontsize=16);
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>default</th>
#       <th>tuned</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>xgboost</th>
#       <td>0.298161 (+4.69%)</td>
#       <td>0.294647 (+3.46%)</td>
#     </tr>
#     <tr>
#       <th>lightgbm</th>
#       <td>0.298774 (+4.91%)</td>
#       <td>0.295660 (+3.82%)</td>
#     </tr>
#     <tr>
#       <th>catboost</th>
#       <td>0.284912 (+0.04%)</td>
#       <td>0.284793 (+0.00%)</td>
#     </tr>
#   </tbody>
# </table>
