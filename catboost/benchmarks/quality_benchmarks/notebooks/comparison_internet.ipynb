# %% [markdown]
# # Comparing algorithms on the Internet dataset
# The data is taken from [this source](https://kdd.ics.uci.edu/databases/internet_usage/internet_usage.html).

# %% [markdown]
# For details on running the comparison, see [this article](https://github.com/catboost/benchmarks/blob/master/comparison_description.pdf).

# %%
from experiment import Experiment
from xgboost_experiment import XGBExperiment
from lightgbm_experiment import LGBExperiment
from catboost_experiment import CABExperiment

# %% [markdown]
# Load the dataset and set parameters for the experiment.

# %%
learning_task = 'classification'
dataset_path = '/media/pool_storage/tsnet-pools-converted/internet/'
n_estimators = 5000
max_hyperopt_evals = 50

experiment = Experiment(learning_task, train_path=dataset_path + 'train_full3',
                        test_path=dataset_path + 'test3', cd_path = dataset_path + 'train_full3.cd')
X_train, y_train, X_test, y_test, cat_cols = experiment.read_data()

# %% [markdown]
# Write a function that does the following:
#
# **Preprocess the dataset:**
# calculate counter values on the training set, transform cat features (for the `XGBoost` and `LightGBM` algorithms), and convert the data to the format of the algorithm. Do the same thing with all pairs after splitting them into cross validation folds.
#
# **Select the optimal number of trees for the algorithm with the default parameters:** for each fold and each number of trees, get the result of the algorithm trained on the other four folds, average the results for each number of trees, and choose the best one.
#
# **Assess the quality of the algorithm with the default parameters on a test dataset:** train the algorithm with the number of trees obtained in the previous step, and calculate the metric value on the test dataset.
#
# **Tune parameters for the algorithm using `Hyperopt`:** on each `Hyperopt` iteration of the algorithm, the best value of trees is selected and the metric for cross validation is calculated.
#
# **Show results on the test dataset for the algorithm with the tuned parameters:** train the algorithm with the optimal parameters and the number of trees obtained in the previous step, and calculate the metric value on the test dataset.

# %%
import numpy as np

def run_experiment(Experiment, title):
    experiment = Experiment(learning_task, max_hyperopt_evals=max_hyperopt_evals,
                            n_estimators=n_estimators)
    cv_pairs, (dtrain, dtest) = experiment.split_and_preprocess(X_train.copy(), y_train, 
                                                                X_test.copy(), y_test, 
                                                                cat_cols, n_splits=5)
 
    default_cv_result = experiment.run_cv(cv_pairs)
    experiment.print_result(default_cv_result, 'Default {} result on cv'.format(title))

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')

    default_test_losses = []
    for seed in range(5):
        test_result = experiment.run_test(dtrain, dtest, X_test, params=default_cv_result['params'],
                                          n_estimators=default_cv_result['best_n_estimators'], seed=seed)
        default_test_losses.append(test_result['loss'])
        print 'For seed=%d Test\'s %s : %.5f' % (seed, experiment.metric, default_test_losses[-1])
    print '\nTest\'s %s mean: %.5f, Test\'s %s std: %.5f' % (experiment.metric, np.mean(default_test_losses),
                                                             experiment.metric, np.std(default_test_losses))

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')
    print('Hyperopt iterations:\n\n')

    tuned_cv_result = experiment.optimize_params(cv_pairs)

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')

    experiment.print_result(tuned_cv_result, 'Tuned {} result on cv'.format(title))

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')

    tuned_test_losses = []
    for seed in range(5):
        test_result = experiment.run_test(dtrain, dtest, X_test, params=tuned_cv_result['params'],
                                          n_estimators=tuned_cv_result['best_n_estimators'], seed=seed)
        tuned_test_losses.append(test_result['loss'])
        print 'For seed=%d Test\'s %s : %.5f' % (seed, experiment.metric, tuned_test_losses[-1])
    print '\nTest\'s %s mean: %.5f, Test\'s %s std: %.5f' % (experiment.metric, np.mean(tuned_test_losses),
                                                             experiment.metric, np.std(tuned_test_losses))

    return np.mean(default_test_losses), np.mean(tuned_test_losses)

# %% [markdown]
# ## `XGBoost`

# %%
xgb_default_test_result, xgb_tuned_test_result = run_experiment(XGBExperiment, "XGBoost")
# Out:
# Default XGBoost result on cv:
#
# logloss = 0.2443806
# best_n_estimators = 23
# params = {'colsample_bytree': 1.0, 'silent': 1, 'eval_metric': 'logloss', 'colsample_bylevel': 1.0, 'min_child_weight': 1, 'subsample': 1.0, 'eta': 0.3, 'objective': 'binary:logistic', 'alpha': 0, 'seed': 0, 'max_depth': 6, 'gamma': 0, 'lambda': 1}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Default XGBoost result on test:
#
# For seed=0 Test's logloss : 0.234678
# For seed=1 Test's logloss : 0.234678
# For seed=2 Test's logloss : 0.234678
# For seed=3 Test's logloss : 0.234678
# For seed=4 Test's logloss : 0.234678
#
# Test's logloss mean: 0.234678, Test's logloss std: 0.000000
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Hyperopt iterations:
#
# [1/50]	eval_time=73.37 sec	current_logloss=0.236941	min_logloss=0.236941
# [2/50]	eval_time=80.94 sec	current_logloss=0.236054	min_logloss=0.236054
# [3/50]	eval_time=32.35 sec	current_logloss=0.248053	min_logloss=0.236054
# [4/50]	eval_time=44.52 sec	current_logloss=0.239847	min_logloss=0.236054
# [5/50]	eval_time=56.36 sec	current_logloss=0.241323	min_logloss=0.236054
# [6/50]	eval_time=66.16 sec	current_logloss=0.236972	min_logloss=0.236054
# [7/50]	eval_time=33.14 sec	current_logloss=0.323473	min_logloss=0.236054
# [8/50]	eval_time=104.24 sec	current_logloss=0.234717	min_logloss=0.234717
# [9/50]	eval_time=63.52 sec	current_logloss=0.252910	min_logloss=0.234717
# [10/50]	eval_time=182.26 sec	current_logloss=0.244119	min_logloss=0.234717
# [11/50]	eval_time=45.20 sec	current_logloss=0.241770	min_logloss=0.234717
# [12/50]	eval_time=64.26 sec	current_logloss=0.243098	min_logloss=0.234717
# [13/50]	eval_time=47.54 sec	current_logloss=0.244100	min_logloss=0.234717
# [14/50]	eval_time=73.29 sec	current_logloss=0.236154	min_logloss=0.234717
# [15/50]	eval_time=162.70 sec	current_logloss=0.240267	min_logloss=0.234717
# [16/50]	eval_time=87.92 sec	current_logloss=0.233957	min_logloss=0.233957
# [17/50]	eval_time=115.09 sec	current_logloss=0.239228	min_logloss=0.233957
# [18/50]	eval_time=38.01 sec	current_logloss=0.238725	min_logloss=0.233957
# [19/50]	eval_time=38.11 sec	current_logloss=0.238758	min_logloss=0.233957
# [20/50]	eval_time=41.46 sec	current_logloss=0.242230	min_logloss=0.233957
# [21/50]	eval_time=85.37 sec	current_logloss=0.242566	min_logloss=0.233957
# [22/50]	eval_time=42.50 sec	current_logloss=0.260465	min_logloss=0.233957
# [23/50]	eval_time=101.96 sec	current_logloss=0.234723	min_logloss=0.233957
# [24/50]	eval_time=92.62 sec	current_logloss=0.236475	min_logloss=0.233957
# [25/50]	eval_time=75.45 sec	current_logloss=0.240627	min_logloss=0.233957
# [26/50]	eval_time=98.86 sec	current_logloss=0.244853	min_logloss=0.233957
# [27/50]	eval_time=67.92 sec	current_logloss=0.238997	min_logloss=0.233957
# [28/50]	eval_time=185.77 sec	current_logloss=0.244716	min_logloss=0.233957
# [29/50]	eval_time=72.04 sec	current_logloss=0.234354	min_logloss=0.233957
# [30/50]	eval_time=79.95 sec	current_logloss=0.242746	min_logloss=0.233957
# [31/50]	eval_time=76.30 sec	current_logloss=0.235423	min_logloss=0.233957
# [32/50]	eval_time=43.51 sec	current_logloss=0.248947	min_logloss=0.233957
# [33/50]	eval_time=76.29 sec	current_logloss=0.233497	min_logloss=0.233497
# [34/50]	eval_time=74.52 sec	current_logloss=0.233729	min_logloss=0.233497
# [35/50]	eval_time=48.72 sec	current_logloss=0.239548	min_logloss=0.233497
# [36/50]	eval_time=89.37 sec	current_logloss=0.247224	min_logloss=0.233497
# [37/50]	eval_time=84.33 sec	current_logloss=0.234980	min_logloss=0.233497
# [38/50]	eval_time=116.80 sec	current_logloss=0.234818	min_logloss=0.233497
# [39/50]	eval_time=43.58 sec	current_logloss=0.243674	min_logloss=0.233497
# [40/50]	eval_time=81.26 sec	current_logloss=0.236126	min_logloss=0.233497
# [41/50]	eval_time=34.36 sec	current_logloss=0.273041	min_logloss=0.233497
# [42/50]	eval_time=52.74 sec	current_logloss=0.238168	min_logloss=0.233497
# [43/50]	eval_time=57.31 sec	current_logloss=0.250641	min_logloss=0.233497
# [44/50]	eval_time=82.29 sec	current_logloss=0.233506	min_logloss=0.233497
# [45/50]	eval_time=105.85 sec	current_logloss=0.236077	min_logloss=0.233497
# [46/50]	eval_time=89.40 sec	current_logloss=0.235097	min_logloss=0.233497
# [47/50]	eval_time=140.90 sec	current_logloss=0.240440	min_logloss=0.233497
# [48/50]	eval_time=133.13 sec	current_logloss=0.239868	min_logloss=0.233497
# [49/50]	eval_time=74.30 sec	current_logloss=0.237243	min_logloss=0.233497
# [50/50]	eval_time=56.18 sec	current_logloss=0.235559	min_logloss=0.233497
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned XGBoost result on cv:
#
# logloss = 0.2334968
# best_n_estimators = 2513
# params = {'colsample_bytree': 0.5982289943240544, 'silent': 1, 'eval_metric': 'logloss', 'colsample_bylevel': 0.6437548867421011, 'min_child_weight': 0.24656051670412105, 'subsample': 0.81140650909387, 'eta': 0.004083614738327742, 'objective': 'binary:logistic', 'alpha': 0, 'seed': 0, 'max_depth': 5, 'gamma': 0.0063464034890371715, 'lambda': 0.00017964887930464898}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned XGBoost result on test:
#
# For seed=0 Test's logloss : 0.225642
# For seed=1 Test's logloss : 0.225081
# For seed=2 Test's logloss : 0.225423
# For seed=3 Test's logloss : 0.225217
# For seed=4 Test's logloss : 0.225254
#
# Test's logloss mean: 0.225323, Test's logloss std: 0.000193

# %% [markdown]
# ## `LightGBM`

# %%
lgb_default_test_result, lgb_tuned_test_result = run_experiment(LGBExperiment, "LightGBM")
# Out:
# Default LightGBM result on cv:
#
# logloss = 0.243003043474
# best_n_estimators = 64
# params = {'feature_fraction_seed': 0, 'num_leaves': 127, 'verbose': -1, 'bagging_seed': 0, 'lambda_l1': 0, 'drop_seed': 0, 'learning_rate': 0.1, 'lambda_l2': 0, 'data_random_seed': 0, 'bagging_fraction': 1.0, 'min_data_in_leaf': 100, 'max_bin': 255, 'objective': 'binary', 'bagging_freq': 1, 'metric': 'binary_logloss', 'min_sum_hessian_in_leaf': 10, 'feature_fraction': 1.0}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Default LightGBM result on test:
#
# For seed=0 Test's logloss : 0.236269
# For seed=1 Test's logloss : 0.236269
# For seed=2 Test's logloss : 0.236269
# For seed=3 Test's logloss : 0.236269
# For seed=4 Test's logloss : 0.236269
#
# Test's logloss mean: 0.236269, Test's logloss std: 0.000000
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Hyperopt iterations:
#
# [1/50]	eval_time=18.19 sec	current_logloss=0.246272	min_logloss=0.246272
# [2/50]	eval_time=9.83 sec	current_logloss=0.257260	min_logloss=0.246272
# [3/50]	eval_time=58.22 sec	current_logloss=0.239641	min_logloss=0.239641
# [4/50]	eval_time=9.53 sec	current_logloss=0.267376	min_logloss=0.239641
# [5/50]	eval_time=15.89 sec	current_logloss=0.248113	min_logloss=0.239641
# [6/50]	eval_time=394.81 sec	current_logloss=0.253277	min_logloss=0.239641
# [7/50]	eval_time=61.30 sec	current_logloss=0.241661	min_logloss=0.239641
# [8/50]	eval_time=12.11 sec	current_logloss=0.248703	min_logloss=0.239641
# [9/50]	eval_time=16.51 sec	current_logloss=0.255403	min_logloss=0.239641
# [10/50]	eval_time=23.31 sec	current_logloss=0.246554	min_logloss=0.239641
# [11/50]	eval_time=41.64 sec	current_logloss=0.234388	min_logloss=0.234388
# [12/50]	eval_time=18.83 sec	current_logloss=0.261320	min_logloss=0.234388
# [13/50]	eval_time=18.82 sec	current_logloss=0.277814	min_logloss=0.234388
# [14/50]	eval_time=12.72 sec	current_logloss=0.246069	min_logloss=0.234388
# [15/50]	eval_time=13.77 sec	current_logloss=0.247970	min_logloss=0.234388
# [16/50]	eval_time=14.14 sec	current_logloss=0.355679	min_logloss=0.234388
# [17/50]	eval_time=13.22 sec	current_logloss=0.269672	min_logloss=0.234388
# [18/50]	eval_time=277.23 sec	current_logloss=0.243121	min_logloss=0.234388
# [19/50]	eval_time=105.83 sec	current_logloss=0.266447	min_logloss=0.234388
# [20/50]	eval_time=17.99 sec	current_logloss=0.257632	min_logloss=0.234388
# [21/50]	eval_time=27.93 sec	current_logloss=0.231942	min_logloss=0.231942
# [22/50]	eval_time=30.23 sec	current_logloss=0.231855	min_logloss=0.231855
# [23/50]	eval_time=26.10 sec	current_logloss=0.231339	min_logloss=0.231339
# [24/50]	eval_time=22.93 sec	current_logloss=0.231051	min_logloss=0.231051
# [25/50]	eval_time=18.33 sec	current_logloss=0.236655	min_logloss=0.231051
# [26/50]	eval_time=17.61 sec	current_logloss=0.237042	min_logloss=0.231051
# [27/50]	eval_time=20.53 sec	current_logloss=0.232357	min_logloss=0.231051
# [28/50]	eval_time=10.43 sec	current_logloss=0.258831	min_logloss=0.231051
# [29/50]	eval_time=10.25 sec	current_logloss=0.259782	min_logloss=0.231051
# [30/50]	eval_time=30.35 sec	current_logloss=0.254770	min_logloss=0.231051
# [31/50]	eval_time=22.02 sec	current_logloss=0.253176	min_logloss=0.231051
# [32/50]	eval_time=15.60 sec	current_logloss=0.240689	min_logloss=0.231051
# [33/50]	eval_time=43.26 sec	current_logloss=0.233633	min_logloss=0.231051
# [34/50]	eval_time=9.83 sec	current_logloss=0.257481	min_logloss=0.231051
# [35/50]	eval_time=29.35 sec	current_logloss=0.243296	min_logloss=0.231051
# [36/50]	eval_time=36.30 sec	current_logloss=0.243844	min_logloss=0.231051
# [37/50]	eval_time=23.97 sec	current_logloss=0.233221	min_logloss=0.231051
# [38/50]	eval_time=52.43 sec	current_logloss=0.236875	min_logloss=0.231051
# [39/50]	eval_time=10.04 sec	current_logloss=0.257035	min_logloss=0.231051
# [40/50]	eval_time=10.44 sec	current_logloss=0.256856	min_logloss=0.231051
# [41/50]	eval_time=109.72 sec	current_logloss=0.240329	min_logloss=0.231051
# [42/50]	eval_time=10.87 sec	current_logloss=0.257346	min_logloss=0.231051
# [43/50]	eval_time=14.25 sec	current_logloss=0.241642	min_logloss=0.231051
# [44/50]	eval_time=31.93 sec	current_logloss=0.238409	min_logloss=0.231051
# [45/50]	eval_time=13.10 sec	current_logloss=0.243963	min_logloss=0.231051
# [46/50]	eval_time=129.78 sec	current_logloss=0.241633	min_logloss=0.231051
# [47/50]	eval_time=48.94 sec	current_logloss=0.238538	min_logloss=0.231051
# [48/50]	eval_time=20.76 sec	current_logloss=0.233957	min_logloss=0.231051
# [49/50]	eval_time=193.49 sec	current_logloss=0.258473	min_logloss=0.231051
# [50/50]	eval_time=21.13 sec	current_logloss=0.239525	min_logloss=0.231051
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned LightGBM result on cv:
#
# logloss = 0.231050666625
# best_n_estimators = 1828
# params = {'num_leaves': 8, 'verbose': -1, 'bagging_seed': 0, 'metric': 'binary_logloss', 'data_random_seed': 0, 'min_data_in_leaf': 16, 'bagging_fraction': 0.9046010662322765, 'min_sum_hessian_in_leaf': 1.271575758364032e-05, 'feature_fraction_seed': 0, 'lambda_l1': 0.016012980104284796, 'bagging_freq': 1, 'lambda_l2': 0, 'objective': 'binary', 'drop_seed': 0, 'learning_rate': 0.006879696425995826, 'feature_fraction': 0.9957686774658463}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned LightGBM result on test:
#
# For seed=0 Test's logloss : 0.223862
# For seed=1 Test's logloss : 0.223159
# For seed=2 Test's logloss : 0.222566
# For seed=3 Test's logloss : 0.223426
# For seed=4 Test's logloss : 0.222757
#
# Test's logloss mean: 0.223154, Test's logloss std: 0.000464

# %% [markdown]
# ## `CatBoost`

# %%
cab_default_test_result, cab_tuned_test_result = run_experiment(CABExperiment, "CatBoost")
# Out:
# Default CatBoost result on cv:
#
# logloss = 0.22724536194
# best_n_estimators = 785
# params = {'rsm': 1.0, 'iterations': 785, 'random_seed': 4, 'verbose': False, 'thread_count': 16, 'learning_rate': 0.03, 'ctr_description': ['Borders', 'CounterMax'], 'depth': 6, 'fold_len_multiplier': 2, 'loss_function': 'Logloss', 'ctr_border_count': 16, 'l2_leaf_reg': 3, 'leaf_estimation_method': 'Newton', 'gradient_iterations': 10, 'border_count': 128, 'used_ram_limit': 100000000000}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Default CatBoost result on test:
#
# For seed=0 Test's logloss : 0.220453
# For seed=1 Test's logloss : 0.220882
# For seed=2 Test's logloss : 0.219509
# For seed=3 Test's logloss : 0.220385
# For seed=4 Test's logloss : 0.219801
#
# Test's logloss mean: 0.220206, Test's logloss std: 0.000490
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Hyperopt iterations:
#
# [1/50]	eval_time=325.64 sec	current_logloss=0.221604	min_logloss=0.221604
# [2/50]	eval_time=576.67 sec	current_logloss=0.226856	min_logloss=0.221604
# [3/50]	eval_time=295.96 sec	current_logloss=0.220255	min_logloss=0.220255
# [4/50]	eval_time=311.90 sec	current_logloss=0.221214	min_logloss=0.220255
# [5/50]	eval_time=648.38 sec	current_logloss=0.226856	min_logloss=0.220255
# [6/50]	eval_time=321.08 sec	current_logloss=0.221613	min_logloss=0.220255
# [7/50]	eval_time=307.75 sec	current_logloss=0.219633	min_logloss=0.219633
# [8/50]	eval_time=434.23 sec	current_logloss=0.221745	min_logloss=0.219633
# [9/50]	eval_time=569.64 sec	current_logloss=0.233823	min_logloss=0.219633
# [10/50]	eval_time=674.78 sec	current_logloss=0.224024	min_logloss=0.219633
# [11/50]	eval_time=547.76 sec	current_logloss=0.223419	min_logloss=0.219633
# [12/50]	eval_time=561.47 sec	current_logloss=0.222209	min_logloss=0.219633
# [13/50]	eval_time=319.86 sec	current_logloss=0.220319	min_logloss=0.219633
# [14/50]	eval_time=429.73 sec	current_logloss=0.222299	min_logloss=0.219633
# [15/50]	eval_time=569.53 sec	current_logloss=0.223964	min_logloss=0.219633
# [16/50]	eval_time=439.23 sec	current_logloss=0.225041	min_logloss=0.219633
# [17/50]	eval_time=685.00 sec	current_logloss=0.230159	min_logloss=0.219633
# [18/50]	eval_time=565.00 sec	current_logloss=0.224841	min_logloss=0.219633
# [19/50]	eval_time=329.16 sec	current_logloss=0.222300	min_logloss=0.219633
# [20/50]	eval_time=436.18 sec	current_logloss=0.223858	min_logloss=0.219633
# [21/50]	eval_time=297.45 sec	current_logloss=0.220818	min_logloss=0.219633
# [22/50]	eval_time=294.96 sec	current_logloss=0.219249	min_logloss=0.219249
# [23/50]	eval_time=298.14 sec	current_logloss=0.219333	min_logloss=0.219249
# [24/50]	eval_time=296.85 sec	current_logloss=0.219198	min_logloss=0.219198
# [25/50]	eval_time=296.17 sec	current_logloss=0.219235	min_logloss=0.219198
# [26/50]	eval_time=302.73 sec	current_logloss=0.218632	min_logloss=0.218632
# [27/50]	eval_time=304.63 sec	current_logloss=0.218644	min_logloss=0.218632
# [28/50]	eval_time=307.70 sec	current_logloss=0.219131	min_logloss=0.218632
# [29/50]	eval_time=321.68 sec	current_logloss=0.220478	min_logloss=0.218632
# [30/50]	eval_time=312.97 sec	current_logloss=0.219057	min_logloss=0.218632
# [31/50]	eval_time=307.12 sec	current_logloss=0.220240	min_logloss=0.218632
# [32/50]	eval_time=324.64 sec	current_logloss=0.227339	min_logloss=0.218632
# [33/50]	eval_time=300.14 sec	current_logloss=0.219497	min_logloss=0.218632
# [34/50]	eval_time=311.61 sec	current_logloss=0.220496	min_logloss=0.218632
# [35/50]	eval_time=317.53 sec	current_logloss=0.219781	min_logloss=0.218632
# [36/50]	eval_time=419.66 sec	current_logloss=0.240034	min_logloss=0.218632
# [37/50]	eval_time=317.41 sec	current_logloss=0.220023	min_logloss=0.218632
# [38/50]	eval_time=318.15 sec	current_logloss=0.218893	min_logloss=0.218632
# [39/50]	eval_time=428.99 sec	current_logloss=0.220442	min_logloss=0.218632
# [40/50]	eval_time=563.51 sec	current_logloss=0.221955	min_logloss=0.218632
# [41/50]	eval_time=307.77 sec	current_logloss=0.220589	min_logloss=0.218632
# [42/50]	eval_time=534.39 sec	current_logloss=0.222125	min_logloss=0.218632
# [43/50]	eval_time=418.87 sec	current_logloss=0.219473	min_logloss=0.218632
# [44/50]	eval_time=325.16 sec	current_logloss=0.221106	min_logloss=0.218632
# [45/50]	eval_time=561.66 sec	current_logloss=0.222196	min_logloss=0.218632
# [46/50]	eval_time=418.17 sec	current_logloss=0.219407	min_logloss=0.218632
# [47/50]	eval_time=550.88 sec	current_logloss=0.224232	min_logloss=0.218632
# [48/50]	eval_time=300.31 sec	current_logloss=0.220167	min_logloss=0.218632
# [49/50]	eval_time=431.37 sec	current_logloss=0.220461	min_logloss=0.218632
# [50/50]	eval_time=565.34 sec	current_logloss=0.223566	min_logloss=0.218632
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned CatBoost result on cv:
#
# logloss = 0.21863241814
# best_n_estimators = 1925
# params = {'random_seed': 4, 'verbose': False, 'thread_count': 16, 'learning_rate': 0.017674094213310874, 'ctr_border_count': 16, 'ctr_description': ('Borders', 'CounterMax'), 'iterations': 1925, 'one_hot_max_size': 25, 'bagging_temperature': 0.1274347868898255, 'gradient_iterations': 1, 'random_strength': 20, 'depth': 6, 'loss_function': 'Logloss', 'l2_leaf_reg': 8.963458165128763, 'border_count': 128, 'used_ram_limit': 100000000000}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned CatBoost result on test:
#
# For seed=0 Test's logloss : 0.209870
# For seed=1 Test's logloss : 0.209623
# For seed=2 Test's logloss : 0.207230
# For seed=3 Test's logloss : 0.207628
# For seed=4 Test's logloss : 0.209387
#
# Test's logloss mean: 0.208748, Test's logloss std: 0.001095

# %% [markdown]
# ## Comparing results
#
# The final table with metric values on the test dataset.

# %%
import pandas as pd
import numpy as np
from IPython.display import HTML, display
# %pylab inline --no-import-all

test_results = np.array([
    (xgb_default_test_result, xgb_tuned_test_result),
    (lgb_default_test_result, lgb_tuned_test_result),
    (cab_default_test_result, cab_tuned_test_result)
])

diff = 100 * test_results / test_results[2,1] - 100

res = [['{:.6f} ({:+.2f}%)'.format(test_results[i, j], diff[i, j]) for j in range(2)] for i in range(3)]

display(HTML(pd.DataFrame(res, columns=['default', 'tuned'], index=['xgboost', 'lightgbm', 'catboost']).to_html()))

results = [
    ('Tuned CatBoost',   cab_tuned_test_result),
    ('Default CatBoost', cab_default_test_result),
    ('Tuned XGBoost',    xgb_tuned_test_result),
    ('Default XGBoost',  xgb_default_test_result),
    ('Tuned LightGBM',   lgb_tuned_test_result),
    ('Default LightGBM', lgb_default_test_result),
]
names = ['%s\n%.5f' % (name, loss) for name, loss in results]

plt.figure(figsize=(20, 7))
plt.scatter(range(6), zip(*results)[1], s=150)
plt.xticks(range(6), names, fontsize=15)
plt.yticks(fontsize=12)
plt.title('Comparison', fontsize=20)
plt.ylabel(experiment.metric, fontsize=16);
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>default</th>
#       <th>tuned</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>xgboost</th>
#       <td>0.234678 (+12.42%)</td>
#       <td>0.225323 (+7.94%)</td>
#     </tr>
#     <tr>
#       <th>lightgbm</th>
#       <td>0.236269 (+13.18%)</td>
#       <td>0.223154 (+6.90%)</td>
#     </tr>
#     <tr>
#       <th>catboost</th>
#       <td>0.220206 (+5.49%)</td>
#       <td>0.208748 (+0.00%)</td>
#     </tr>
#   </tbody>
# </table>
