# %% [markdown]
# # Comparing algorithms on the Adult dataset
# The data is taken from [this source](https://archive.ics.uci.edu/ml/datasets/Adult).

# %% [markdown]
# For details on running the comparison, see [this article](https://github.com/catboost/benchmarks/blob/master/comparison_description.pdf).

# %%
from experiment import Experiment
from xgboost_experiment import XGBExperiment
from lightgbm_experiment import LGBExperiment
from catboost_experiment import CABExperiment

# %% [markdown]
# Load the dataset and set parameters for the experiment.

# %%
learning_task = 'classification'
dataset_path = '/media/pool_storage/tsnet-pools-converted/adult/'
n_estimators = 5000
max_hyperopt_evals = 50

experiment = Experiment(learning_task, train_path=dataset_path + 'train_full3',
                        test_path=dataset_path + 'test3', cd_path = dataset_path + 'train_full3.cd')
X_train, y_train, X_test, y_test, cat_cols = experiment.read_data()

# %% [markdown]
# Write a function that does the following:
#
# **Preprocess the dataset:**
# calculate counter values on the training set, transform cat features (for the `XGBoost` and `LightGBM` algorithms), and convert the data to the format of the algorithm. Do the same thing with all pairs after splitting them into cross validation folds.
#
# **Select the optimal number of trees for the algorithm with the default parameters:** for each fold and each number of trees, get the result of the algorithm trained on the other four folds, average the results for each number of trees, and choose the best one.
#
# **Assess the quality of the algorithm with the default parameters on a test dataset:** train the algorithm with the number of trees obtained in the previous step, and calculate the metric value on the test dataset.
#
# **Tune parameters for the algorithm using `Hyperopt`:** on each `Hyperopt` iteration of the algorithm, the best value of trees is selected and the metric for cross validation is calculated.
#
# **Show results on the test dataset for the algorithm with the tuned parameters:** train the algorithm with the optimal parameters and the number of trees obtained in the previous step, and calculate the metric value on the test dataset.

# %%
import numpy as np

def run_experiment(Experiment, title):
    experiment = Experiment(learning_task, max_hyperopt_evals=max_hyperopt_evals,
                            n_estimators=n_estimators)
    cv_pairs, (dtrain, dtest) = experiment.split_and_preprocess(X_train.copy(), y_train, 
                                                                X_test.copy(), y_test, 
                                                                cat_cols, n_splits=5)
 
    default_cv_result = experiment.run_cv(cv_pairs)
    experiment.print_result(default_cv_result, 'Default {} result on cv'.format(title))

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')

    default_test_losses = []
    for seed in range(5):
        test_result = experiment.run_test(dtrain, dtest, X_test, params=default_cv_result['params'],
                                          n_estimators=default_cv_result['best_n_estimators'], seed=seed)
        default_test_losses.append(test_result['loss'])
        print 'For seed=%d Test\'s %s : %.5f' % (seed, experiment.metric, default_test_losses[-1])
    print '\nTest\'s %s mean: %.5f, Test\'s %s std: %.5f' % (experiment.metric, np.mean(default_test_losses),
                                                             experiment.metric, np.std(default_test_losses))

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')
    print('Hyperopt iterations:\n\n')

    tuned_cv_result = experiment.optimize_params(cv_pairs)

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')

    experiment.print_result(tuned_cv_result, 'Tuned {} result on cv'.format(title))

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')

    tuned_test_losses = []
    for seed in range(5):
        test_result = experiment.run_test(dtrain, dtest, X_test, params=tuned_cv_result['params'],
                                          n_estimators=tuned_cv_result['best_n_estimators'], seed=seed)
        tuned_test_losses.append(test_result['loss'])
        print 'For seed=%d Test\'s %s : %.5f' % (seed, experiment.metric, tuned_test_losses[-1])
    print '\nTest\'s %s mean: %.5f, Test\'s %s std: %.5f' % (experiment.metric, np.mean(tuned_test_losses),
                                                             experiment.metric, np.std(tuned_test_losses))

    return np.mean(default_test_losses), np.mean(tuned_test_losses)

# %% [markdown]
# ## `XGBoost`

# %%
xgb_default_test_result, xgb_tuned_test_result = run_experiment(XGBExperiment, "XGBoost")
# Out:
# Default XGBoost result on cv:
#
# logloss = 0.2818092
# best_n_estimators = 31
# params = {'colsample_bytree': 1.0, 'silent': 1, 'eval_metric': 'logloss', 'colsample_bylevel': 1.0, 'min_child_weight': 1, 'subsample': 1.0, 'eta': 0.3, 'objective': 'binary:logistic', 'alpha': 0, 'seed': 0, 'max_depth': 6, 'gamma': 0, 'lambda': 1}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Default XGBoost result on test:
#
# For seed=0 Test's logloss : 0.280087
# For seed=1 Test's logloss : 0.280087
# For seed=2 Test's logloss : 0.280087
# For seed=3 Test's logloss : 0.280087
# For seed=4 Test's logloss : 0.280087
#
# Test's logloss mean: 0.280087, Test's logloss std: 0.000000
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Hyperopt iterations:
#
# [1/50]	eval_time=314.63 sec	current_logloss=0.279691	min_logloss=0.279691
# [2/50]	eval_time=447.33 sec	current_logloss=0.279810	min_logloss=0.279691
# [3/50]	eval_time=397.07 sec	current_logloss=0.288587	min_logloss=0.279691
# [4/50]	eval_time=250.06 sec	current_logloss=0.282513	min_logloss=0.279691
# [5/50]	eval_time=233.16 sec	current_logloss=0.297431	min_logloss=0.279691
# [6/50]	eval_time=280.11 sec	current_logloss=0.282618	min_logloss=0.279691
# [7/50]	eval_time=165.13 sec	current_logloss=0.303761	min_logloss=0.279691
# [8/50]	eval_time=424.35 sec	current_logloss=0.279074	min_logloss=0.279074
# [9/50]	eval_time=367.79 sec	current_logloss=0.295324	min_logloss=0.279074
# [10/50]	eval_time=780.53 sec	current_logloss=0.282218	min_logloss=0.279074
# [11/50]	eval_time=216.92 sec	current_logloss=0.284931	min_logloss=0.279074
# [12/50]	eval_time=645.75 sec	current_logloss=0.281704	min_logloss=0.279074
# [13/50]	eval_time=327.88 sec	current_logloss=0.283501	min_logloss=0.279074
# [14/50]	eval_time=275.53 sec	current_logloss=0.281009	min_logloss=0.279074
# [15/50]	eval_time=750.44 sec	current_logloss=0.281191	min_logloss=0.279074
# [16/50]	eval_time=413.77 sec	current_logloss=0.285918	min_logloss=0.279074
# [17/50]	eval_time=571.88 sec	current_logloss=0.280130	min_logloss=0.279074
# [18/50]	eval_time=171.62 sec	current_logloss=0.286359	min_logloss=0.279074
# [19/50]	eval_time=189.03 sec	current_logloss=0.280198	min_logloss=0.279074
# [20/50]	eval_time=519.46 sec	current_logloss=0.282937	min_logloss=0.279074
# [21/50]	eval_time=344.77 sec	current_logloss=0.280439	min_logloss=0.279074
# [22/50]	eval_time=380.34 sec	current_logloss=0.279728	min_logloss=0.279074
# [23/50]	eval_time=405.15 sec	current_logloss=0.279012	min_logloss=0.279012
# [24/50]	eval_time=388.19 sec	current_logloss=0.278832	min_logloss=0.278832
# [25/50]	eval_time=589.03 sec	current_logloss=0.284202	min_logloss=0.278832
# [26/50]	eval_time=500.98 sec	current_logloss=0.290516	min_logloss=0.278832
# [27/50]	eval_time=426.40 sec	current_logloss=0.286576	min_logloss=0.278832
# [28/50]	eval_time=504.90 sec	current_logloss=0.278848	min_logloss=0.278832
# [29/50]	eval_time=542.68 sec	current_logloss=0.279004	min_logloss=0.278832
# [30/50]	eval_time=650.80 sec	current_logloss=0.284755	min_logloss=0.278832
# [31/50]	eval_time=515.17 sec	current_logloss=0.280871	min_logloss=0.278832
# [32/50]	eval_time=582.90 sec	current_logloss=0.300450	min_logloss=0.278832
# [33/50]	eval_time=364.19 sec	current_logloss=0.279022	min_logloss=0.278832
# [34/50]	eval_time=607.71 sec	current_logloss=0.281580	min_logloss=0.278832
# [35/50]	eval_time=475.72 sec	current_logloss=0.281798	min_logloss=0.278832
# [36/50]	eval_time=528.31 sec	current_logloss=0.277550	min_logloss=0.277550
# [37/50]	eval_time=773.91 sec	current_logloss=0.280344	min_logloss=0.277550
# [38/50]	eval_time=446.05 sec	current_logloss=0.278373	min_logloss=0.277550
# [39/50]	eval_time=468.58 sec	current_logloss=0.279696	min_logloss=0.277550
# [40/50]	eval_time=558.80 sec	current_logloss=0.285452	min_logloss=0.277550
# [41/50]	eval_time=433.46 sec	current_logloss=0.282461	min_logloss=0.277550
# [42/50]	eval_time=615.41 sec	current_logloss=0.278816	min_logloss=0.277550
# [43/50]	eval_time=705.71 sec	current_logloss=0.284240	min_logloss=0.277550
# [44/50]	eval_time=303.58 sec	current_logloss=0.312217	min_logloss=0.277550
# [45/50]	eval_time=400.79 sec	current_logloss=0.279310	min_logloss=0.277550
# [46/50]	eval_time=506.45 sec	current_logloss=0.281035	min_logloss=0.277550
# [47/50]	eval_time=267.45 sec	current_logloss=0.285833	min_logloss=0.277550
# [48/50]	eval_time=759.57 sec	current_logloss=0.282192	min_logloss=0.277550
# [49/50]	eval_time=428.07 sec	current_logloss=0.279415	min_logloss=0.277550
# [50/50]	eval_time=303.91 sec	current_logloss=0.280388	min_logloss=0.277550
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned XGBoost result on cv:
#
# logloss = 0.2775502
# best_n_estimators = 2389
# params = {'colsample_bytree': 0.5354643381470408, 'silent': 1, 'eval_metric': 'logloss', 'colsample_bylevel': 0.9742204235895299, 'min_child_weight': 1.79512513187008e-07, 'subsample': 0.5981588026453791, 'eta': 0.004157268437774014, 'objective': 'binary:logistic', 'alpha': 0, 'seed': 0, 'max_depth': 8, 'gamma': 0.0016730818148765804, 'lambda': 0.00011561653736964494}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned XGBoost result on test:
#
# For seed=0 Test's logloss : 0.275293
# For seed=1 Test's logloss : 0.275739
# For seed=2 Test's logloss : 0.275420
# For seed=3 Test's logloss : 0.275434
# For seed=4 Test's logloss : 0.275229
#
# Test's logloss mean: 0.275423, Test's logloss std: 0.000176

# %% [markdown]
# ## `LightGBM`

# %%
lgb_default_test_result, lgb_tuned_test_result = run_experiment(LGBExperiment, "LightGBM")
# Out:
# Default LightGBM result on cv:
#
# logloss = 0.286858408641
# best_n_estimators = 50
# params = {'feature_fraction_seed': 0, 'num_leaves': 127, 'verbose': -1, 'bagging_seed': 0, 'lambda_l1': 0, 'drop_seed': 0, 'learning_rate': 0.1, 'lambda_l2': 0, 'data_random_seed': 0, 'bagging_fraction': 1.0, 'min_data_in_leaf': 100, 'max_bin': 255, 'objective': 'binary', 'bagging_freq': 1, 'metric': 'binary_logloss', 'min_sum_hessian_in_leaf': 10, 'feature_fraction': 1.0}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Default LightGBM result on test:
#
# For seed=0 Test's logloss : 0.287165
# For seed=1 Test's logloss : 0.287165
# For seed=2 Test's logloss : 0.287165
# For seed=3 Test's logloss : 0.287165
# For seed=4 Test's logloss : 0.287165
#
# Test's logloss mean: 0.287165, Test's logloss std: 0.000000
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Hyperopt iterations:
#
# [1/50]	eval_time=218.05 sec	current_logloss=0.286950	min_logloss=0.286950
# [2/50]	eval_time=35.04 sec	current_logloss=0.293177	min_logloss=0.286950
# [3/50]	eval_time=118.41 sec	current_logloss=0.280979	min_logloss=0.280979
# [4/50]	eval_time=32.57 sec	current_logloss=0.321485	min_logloss=0.280979
# [5/50]	eval_time=136.04 sec	current_logloss=0.284301	min_logloss=0.280979
# [6/50]	eval_time=947.74 sec	current_logloss=0.289612	min_logloss=0.280979
# [7/50]	eval_time=174.10 sec	current_logloss=0.284670	min_logloss=0.280979
# [8/50]	eval_time=46.83 sec	current_logloss=0.304810	min_logloss=0.280979
# [9/50]	eval_time=101.34 sec	current_logloss=0.296918	min_logloss=0.280979
# [10/50]	eval_time=181.66 sec	current_logloss=0.290487	min_logloss=0.280979
# [11/50]	eval_time=93.27 sec	current_logloss=0.280379	min_logloss=0.280379
# [12/50]	eval_time=143.99 sec	current_logloss=0.308381	min_logloss=0.280379
# [13/50]	eval_time=131.55 sec	current_logloss=0.295878	min_logloss=0.280379
# [14/50]	eval_time=36.17 sec	current_logloss=0.301773	min_logloss=0.280379
# [15/50]	eval_time=141.43 sec	current_logloss=0.290670	min_logloss=0.280379
# [16/50]	eval_time=78.44 sec	current_logloss=0.331395	min_logloss=0.280379
# [17/50]	eval_time=73.48 sec	current_logloss=0.308057	min_logloss=0.280379
# [18/50]	eval_time=458.54 sec	current_logloss=0.285679	min_logloss=0.280379
# [19/50]	eval_time=719.21 sec	current_logloss=0.293581	min_logloss=0.280379
# [20/50]	eval_time=157.82 sec	current_logloss=0.300387	min_logloss=0.280379
# [21/50]	eval_time=69.03 sec	current_logloss=0.279425	min_logloss=0.279425
# [22/50]	eval_time=67.81 sec	current_logloss=0.279424	min_logloss=0.279424
# [23/50]	eval_time=65.58 sec	current_logloss=0.279379	min_logloss=0.279379
# [24/50]	eval_time=59.76 sec	current_logloss=0.279924	min_logloss=0.279379
# [25/50]	eval_time=52.75 sec	current_logloss=0.281119	min_logloss=0.279379
# [26/50]	eval_time=65.87 sec	current_logloss=0.279753	min_logloss=0.279379
# [27/50]	eval_time=54.56 sec	current_logloss=0.286930	min_logloss=0.279379
# [28/50]	eval_time=42.92 sec	current_logloss=0.297602	min_logloss=0.279379
# [29/50]	eval_time=111.13 sec	current_logloss=0.292910	min_logloss=0.279379
# [30/50]	eval_time=36.40 sec	current_logloss=0.307211	min_logloss=0.279379
# [31/50]	eval_time=168.02 sec	current_logloss=0.287227	min_logloss=0.279379
# [32/50]	eval_time=81.56 sec	current_logloss=0.279313	min_logloss=0.279313
# [33/50]	eval_time=86.38 sec	current_logloss=0.280049	min_logloss=0.279313
# [34/50]	eval_time=41.65 sec	current_logloss=0.282574	min_logloss=0.279313
# [35/50]	eval_time=42.27 sec	current_logloss=0.291662	min_logloss=0.279313
# [36/50]	eval_time=160.24 sec	current_logloss=0.286198	min_logloss=0.279313
# [37/50]	eval_time=56.04 sec	current_logloss=0.279050	min_logloss=0.279050
# [38/50]	eval_time=1016.39 sec	current_logloss=0.302733	min_logloss=0.279050
# [39/50]	eval_time=112.55 sec	current_logloss=0.281219	min_logloss=0.279050
# [40/50]	eval_time=56.64 sec	current_logloss=0.286781	min_logloss=0.279050
# [41/50]	eval_time=35.55 sec	current_logloss=0.291363	min_logloss=0.279050
# [42/50]	eval_time=138.01 sec	current_logloss=0.279659	min_logloss=0.279050
# [43/50]	eval_time=236.98 sec	current_logloss=0.281436	min_logloss=0.279050
# [44/50]	eval_time=33.55 sec	current_logloss=0.334446	min_logloss=0.279050
# [45/50]	eval_time=70.50 sec	current_logloss=0.277768	min_logloss=0.277768
# [46/50]	eval_time=42.17 sec	current_logloss=0.283216	min_logloss=0.277768
# [47/50]	eval_time=116.44 sec	current_logloss=0.291988	min_logloss=0.277768
# [48/50]	eval_time=93.06 sec	current_logloss=0.278022	min_logloss=0.277768
# [49/50]	eval_time=128.47 sec	current_logloss=0.300008	min_logloss=0.277768
# [50/50]	eval_time=321.61 sec	current_logloss=0.288564	min_logloss=0.277768
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned LightGBM result on cv:
#
# logloss = 0.277767610416
# best_n_estimators = 1589
# params = {'num_leaves': 16, 'verbose': -1, 'bagging_seed': 0, 'metric': 'binary_logloss', 'data_random_seed': 0, 'min_data_in_leaf': 2, 'bagging_fraction': 0.8231258721410332, 'min_sum_hessian_in_leaf': 0.0023527955721999202, 'feature_fraction_seed': 0, 'lambda_l1': 0.0009040060631182545, 'bagging_freq': 1, 'lambda_l2': 0, 'objective': 'binary', 'drop_seed': 0, 'learning_rate': 0.01623096612907187, 'feature_fraction': 0.6153146698674108}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned LightGBM result on test:
#
# For seed=0 Test's logloss : 0.275655
# For seed=1 Test's logloss : 0.275702
# For seed=2 Test's logloss : 0.276311
# For seed=3 Test's logloss : 0.276481
# For seed=4 Test's logloss : 0.275940
#
# Test's logloss mean: 0.276018, Test's logloss std: 0.000328

# %% [markdown]
# ## `CatBoost`

# %%
cab_default_test_result, cab_tuned_test_result = run_experiment(CABExperiment, "CatBoost")
# Out:
# Default CatBoost result on cv:
#
# logloss = 0.27589891394
# best_n_estimators = 1441
# params = {'rsm': 1.0, 'iterations': 1441, 'random_seed': 4, 'verbose': False, 'thread_count': 16, 'learning_rate': 0.03, 'ctr_description': ['Borders', 'CounterMax'], 'depth': 6, 'fold_len_multiplier': 2, 'loss_function': 'Logloss', 'ctr_border_count': 16, 'l2_leaf_reg': 3, 'leaf_estimation_method': 'Newton', 'gradient_iterations': 10, 'border_count': 128, 'used_ram_limit': 100000000000}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Default CatBoost result on test:
#
# For seed=0 Test's logloss : 0.273433
# For seed=1 Test's logloss : 0.273113
# For seed=2 Test's logloss : 0.272833
# For seed=3 Test's logloss : 0.273250
# For seed=4 Test's logloss : 0.272263
#
# Test's logloss mean: 0.272978, Test's logloss std: 0.000408
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Hyperopt iterations:
#
# [1/50]	eval_time=541.84 sec	current_logloss=0.275670	min_logloss=0.275670
# [2/50]	eval_time=763.79 sec	current_logloss=0.277393	min_logloss=0.275670
# [3/50]	eval_time=472.36 sec	current_logloss=0.275482	min_logloss=0.275482
# [4/50]	eval_time=525.38 sec	current_logloss=0.274492	min_logloss=0.274492
# [5/50]	eval_time=873.53 sec	current_logloss=0.276304	min_logloss=0.274492
# [6/50]	eval_time=534.61 sec	current_logloss=0.275271	min_logloss=0.274492
# [7/50]	eval_time=510.98 sec	current_logloss=0.273580	min_logloss=0.273580
# [8/50]	eval_time=719.32 sec	current_logloss=0.275689	min_logloss=0.273580
# [9/50]	eval_time=755.30 sec	current_logloss=0.284042	min_logloss=0.273580
# [10/50]	eval_time=913.07 sec	current_logloss=0.274392	min_logloss=0.273580
# [11/50]	eval_time=724.70 sec	current_logloss=0.275224	min_logloss=0.273580
# [12/50]	eval_time=751.87 sec	current_logloss=0.274782	min_logloss=0.273580
# [13/50]	eval_time=529.41 sec	current_logloss=0.274706	min_logloss=0.273580
# [14/50]	eval_time=704.69 sec	current_logloss=0.275523	min_logloss=0.273580
# [15/50]	eval_time=753.30 sec	current_logloss=0.276507	min_logloss=0.273580
# [16/50]	eval_time=724.99 sec	current_logloss=0.278513	min_logloss=0.273580
# [17/50]	eval_time=922.95 sec	current_logloss=0.276666	min_logloss=0.273580
# [18/50]	eval_time=749.44 sec	current_logloss=0.275495	min_logloss=0.273580
# [19/50]	eval_time=545.00 sec	current_logloss=0.276611	min_logloss=0.273580
# [20/50]	eval_time=723.51 sec	current_logloss=0.275942	min_logloss=0.273580
# [21/50]	eval_time=911.11 sec	current_logloss=0.273826	min_logloss=0.273580
# [22/50]	eval_time=913.57 sec	current_logloss=0.275503	min_logloss=0.273580
# [23/50]	eval_time=701.70 sec	current_logloss=0.274347	min_logloss=0.273580
# [24/50]	eval_time=900.61 sec	current_logloss=0.274050	min_logloss=0.273580
# [25/50]	eval_time=919.72 sec	current_logloss=0.281539	min_logloss=0.273580
# [26/50]	eval_time=710.45 sec	current_logloss=0.275106	min_logloss=0.273580
# [27/50]	eval_time=698.90 sec	current_logloss=0.274386	min_logloss=0.273580
# [28/50]	eval_time=720.50 sec	current_logloss=0.274185	min_logloss=0.273580
# [29/50]	eval_time=540.46 sec	current_logloss=0.277560	min_logloss=0.273580
# [30/50]	eval_time=908.90 sec	current_logloss=0.274384	min_logloss=0.273580
# [31/50]	eval_time=523.09 sec	current_logloss=0.273749	min_logloss=0.273580
# [32/50]	eval_time=524.12 sec	current_logloss=0.273710	min_logloss=0.273580
# [33/50]	eval_time=521.99 sec	current_logloss=0.274810	min_logloss=0.273580
# [34/50]	eval_time=505.92 sec	current_logloss=0.275940	min_logloss=0.273580
# [35/50]	eval_time=520.94 sec	current_logloss=0.273988	min_logloss=0.273580
# [36/50]	eval_time=523.67 sec	current_logloss=0.274101	min_logloss=0.273580
# [37/50]	eval_time=522.38 sec	current_logloss=0.274320	min_logloss=0.273580
# [38/50]	eval_time=499.24 sec	current_logloss=0.277336	min_logloss=0.273580
# [39/50]	eval_time=516.61 sec	current_logloss=0.273747	min_logloss=0.273580
# [40/50]	eval_time=521.42 sec	current_logloss=0.274413	min_logloss=0.273580
# [41/50]	eval_time=519.99 sec	current_logloss=0.273878	min_logloss=0.273580
# [42/50]	eval_time=521.77 sec	current_logloss=0.273853	min_logloss=0.273580
# [43/50]	eval_time=491.25 sec	current_logloss=0.273317	min_logloss=0.273317
# [44/50]	eval_time=539.21 sec	current_logloss=0.276876	min_logloss=0.273317
# [45/50]	eval_time=479.20 sec	current_logloss=0.273036	min_logloss=0.273036
# [46/50]	eval_time=492.83 sec	current_logloss=0.273825	min_logloss=0.273036
# [47/50]	eval_time=491.41 sec	current_logloss=0.273773	min_logloss=0.273036
# [48/50]	eval_time=515.31 sec	current_logloss=0.273913	min_logloss=0.273036
# [49/50]	eval_time=546.35 sec	current_logloss=0.277155	min_logloss=0.273036
# [50/50]	eval_time=541.71 sec	current_logloss=0.275064	min_logloss=0.273036
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned CatBoost result on cv:
#
# logloss = 0.27303581696
# best_n_estimators = 3472
# params = {'random_seed': 4, 'verbose': False, 'thread_count': 16, 'learning_rate': 0.031243481776440964, 'ctr_border_count': 16, 'ctr_description': ('Borders', 'CounterMax'), 'iterations': 3472, 'one_hot_max_size': 25, 'bagging_temperature': 0.025264671244305793, 'gradient_iterations': 1, 'random_strength': 1, 'depth': 6, 'loss_function': 'Logloss', 'l2_leaf_reg': 5.346757565241074, 'border_count': 128, 'used_ram_limit': 100000000000}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned CatBoost result on test:
#
# For seed=0 Test's logloss : 0.269840
# For seed=1 Test's logloss : 0.269875
# For seed=2 Test's logloss : 0.269799
# For seed=3 Test's logloss : 0.269666
# For seed=4 Test's logloss : 0.269523
#
# Test's logloss mean: 0.269741, Test's logloss std: 0.000130

# %% [markdown]
# ## Comparing results
#
# The final table with metric values on the test dataset.

# %%
import pandas as pd
import numpy as np
from IPython.display import HTML, display
# %pylab inline --no-import-all

test_results = np.array([
    (xgb_default_test_result, xgb_tuned_test_result),
    (lgb_default_test_result, lgb_tuned_test_result),
    (cab_default_test_result, cab_tuned_test_result)
])

diff = 100 * test_results / test_results[2,1] - 100

res = [['{:.6f} ({:+.2f}%)'.format(test_results[i, j], diff[i, j]) for j in range(2)] for i in range(3)]

display(HTML(pd.DataFrame(res, columns=['default', 'tuned'], index=['xgboost', 'lightgbm', 'catboost']).to_html()))

results = [
    ('Tuned CatBoost',   cab_tuned_test_result),
    ('Default CatBoost', cab_default_test_result),
    ('Tuned XGBoost',    xgb_tuned_test_result),
    ('Default XGBoost',  xgb_default_test_result),
    ('Tuned LightGBM',   lgb_tuned_test_result),
    ('Default LightGBM', lgb_default_test_result),
]
names = ['%s\n%.5f' % (name, loss) for name, loss in results]

plt.figure(figsize=(20, 7))
plt.scatter(range(6), zip(*results)[1], s=150)
plt.xticks(range(6), names, fontsize=15)
plt.yticks(fontsize=12)
plt.title('Comparison', fontsize=20)
plt.ylabel(experiment.metric, fontsize=16);
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>default</th>
#       <th>tuned</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>xgboost</th>
#       <td>0.280087 (+3.84%)</td>
#       <td>0.275423 (+2.11%)</td>
#     </tr>
#     <tr>
#       <th>lightgbm</th>
#       <td>0.287165 (+6.46%)</td>
#       <td>0.276018 (+2.33%)</td>
#     </tr>
#     <tr>
#       <th>catboost</th>
#       <td>0.272978 (+1.20%)</td>
#       <td>0.269741 (+0.00%)</td>
#     </tr>
#   </tbody>
# </table>
