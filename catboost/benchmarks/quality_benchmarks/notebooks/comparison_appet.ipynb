# %% [markdown]
# # Comparing algorithms on the Appet dataset
# The data is taken from [this source](http://www.kdd.org/kdd-cup/view/kdd-cup-2009/Data).

# %% [markdown]
# For details on running the comparison, see [this article](https://github.com/catboost/benchmarks/blob/master/comparison_description.pdf).

# %%
from experiment import Experiment
from xgboost_experiment import XGBExperiment
from lightgbm_experiment import LGBExperiment
from catboost_experiment import CABExperiment

# %% [markdown]
# Load the dataset and set parameters for the experiment.

# %%
learning_task = 'classification'
dataset_path = '/media/pool_storage/tsnet-pools-converted/appet/'
n_estimators = 5000
max_hyperopt_evals = 50

experiment = Experiment(learning_task, train_path=dataset_path + 'train_full3',
                        test_path=dataset_path + 'test3', cd_path = dataset_path + 'train_full3.cd')
X_train, y_train, X_test, y_test, cat_cols = experiment.read_data()

# %% [markdown]
# Write a function that does the following:
#
# **Preprocess the dataset:**
# calculate counter values on the training set, transform cat features (for the `XGBoost` and `LightGBM` algorithms), and convert the data to the format of the algorithm. Do the same thing with all pairs after splitting them into cross validation folds.
#
# **Select the optimal number of trees for the algorithm with the default parameters:** for each fold and each number of trees, get the result of the algorithm trained on the other four folds, average the results for each number of trees, and choose the best one.
#
# **Assess the quality of the algorithm with the default parameters on a test dataset:** train the algorithm with the number of trees obtained in the previous step, and calculate the metric value on the test dataset.
#
# **Tune parameters for the algorithm using `Hyperopt`:** on each `Hyperopt` iteration of the algorithm, the best value of trees is selected and the metric for cross validation is calculated.
#
# **Show results on the test dataset for the algorithm with the tuned parameters:** train the algorithm with the optimal parameters and the number of trees obtained in the previous step, and calculate the metric value on the test dataset.

# %%
import numpy as np

def run_experiment(Experiment, title):
    experiment = Experiment(learning_task, max_hyperopt_evals=max_hyperopt_evals,
                            n_estimators=n_estimators)
    cv_pairs, (dtrain, dtest) = experiment.split_and_preprocess(X_train.copy(), y_train, 
                                                                X_test.copy(), y_test, 
                                                                cat_cols, n_splits=5)
 
    default_cv_result = experiment.run_cv(cv_pairs)
    experiment.print_result(default_cv_result, 'Default {} result on cv'.format(title))

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')

    default_test_losses = []
    for seed in range(5):
        test_result = experiment.run_test(dtrain, dtest, X_test, params=default_cv_result['params'],
                                          n_estimators=default_cv_result['best_n_estimators'], seed=seed)
        default_test_losses.append(test_result['loss'])
        print 'For seed=%d Test\'s %s : %.5f' % (seed, experiment.metric, default_test_losses[-1])
    print '\nTest\'s %s mean: %.5f, Test\'s %s std: %.5f' % (experiment.metric, np.mean(default_test_losses),
                                                             experiment.metric, np.std(default_test_losses))

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')
    print('Hyperopt iterations:\n\n')

    tuned_cv_result = experiment.optimize_params(cv_pairs)

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')

    experiment.print_result(tuned_cv_result, 'Tuned {} result on cv'.format(title))

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')

    tuned_test_losses = []
    for seed in range(5):
        test_result = experiment.run_test(dtrain, dtest, X_test, params=tuned_cv_result['params'],
                                          n_estimators=tuned_cv_result['best_n_estimators'], seed=seed)
        tuned_test_losses.append(test_result['loss'])
        print 'For seed=%d Test\'s %s : %.5f' % (seed, experiment.metric, tuned_test_losses[-1])
    print '\nTest\'s %s mean: %.5f, Test\'s %s std: %.5f' % (experiment.metric, np.mean(tuned_test_losses),
                                                             experiment.metric, np.std(tuned_test_losses))

    return np.mean(default_test_losses), np.mean(tuned_test_losses)

# %% [markdown]
# ## `XGBoost`

# %%
xgb_default_test_result, xgb_tuned_test_result = run_experiment(XGBExperiment, "XGBoost")
# Out:
# Default XGBoost result on cv:
#
# logloss = 0.076848
# best_n_estimators = 18
# params = {'colsample_bytree': 1.0, 'silent': 1, 'eval_metric': 'logloss', 'colsample_bylevel': 1.0, 'min_child_weight': 1, 'subsample': 1.0, 'eta': 0.3, 'objective': 'binary:logistic', 'alpha': 0, 'seed': 0, 'max_depth': 6, 'gamma': 0, 'lambda': 1}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Default XGBoost result on test:
#
# For seed=0 Test's logloss : 0.074659
# For seed=1 Test's logloss : 0.074659
# For seed=2 Test's logloss : 0.074659
# For seed=3 Test's logloss : 0.074659
# For seed=4 Test's logloss : 0.074659
#
# Test's logloss mean: 0.074659, Test's logloss std: 0.000000
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Hyperopt iterations:
#
# [1/50]	eval_time=1740.73 sec	current_logloss=0.074446	min_logloss=0.074446
# [2/50]	eval_time=1878.75 sec	current_logloss=0.075643	min_logloss=0.074446
# [3/50]	eval_time=674.01 sec	current_logloss=0.086193	min_logloss=0.074446
# [4/50]	eval_time=854.55 sec	current_logloss=0.074494	min_logloss=0.074446
# [5/50]	eval_time=1110.57 sec	current_logloss=0.074311	min_logloss=0.074311
# [6/50]	eval_time=1283.57 sec	current_logloss=0.074197	min_logloss=0.074197
# [7/50]	eval_time=858.21 sec	current_logloss=0.103859	min_logloss=0.074197
# [8/50]	eval_time=1878.60 sec	current_logloss=0.074969	min_logloss=0.074197
# [9/50]	eval_time=1067.40 sec	current_logloss=0.074830	min_logloss=0.074197
# [10/50]	eval_time=3182.60 sec	current_logloss=0.076708	min_logloss=0.074197
# [11/50]	eval_time=748.47 sec	current_logloss=0.076923	min_logloss=0.074197
# [12/50]	eval_time=1157.90 sec	current_logloss=0.078467	min_logloss=0.074197
# [13/50]	eval_time=763.42 sec	current_logloss=0.078545	min_logloss=0.074197
# [14/50]	eval_time=1341.79 sec	current_logloss=0.074409	min_logloss=0.074197
# [15/50]	eval_time=2504.63 sec	current_logloss=0.075913	min_logloss=0.074197
# [16/50]	eval_time=1338.05 sec	current_logloss=0.074367	min_logloss=0.074197
# [17/50]	eval_time=1941.12 sec	current_logloss=0.076497	min_logloss=0.074197
# [18/50]	eval_time=644.44 sec	current_logloss=0.074420	min_logloss=0.074197
# [19/50]	eval_time=547.86 sec	current_logloss=0.074838	min_logloss=0.074197
# [20/50]	eval_time=668.35 sec	current_logloss=0.079802	min_logloss=0.074197
# [21/50]	eval_time=1257.49 sec	current_logloss=0.074414	min_logloss=0.074197
# [22/50]	eval_time=944.81 sec	current_logloss=0.077623	min_logloss=0.074197
# [23/50]	eval_time=2095.94 sec	current_logloss=0.074669	min_logloss=0.074197
# [24/50]	eval_time=1105.74 sec	current_logloss=0.077284	min_logloss=0.074197
# [25/50]	eval_time=1511.62 sec	current_logloss=0.074497	min_logloss=0.074197
# [26/50]	eval_time=789.83 sec	current_logloss=0.074883	min_logloss=0.074197
# [27/50]	eval_time=936.03 sec	current_logloss=0.074786	min_logloss=0.074197
# [28/50]	eval_time=2307.50 sec	current_logloss=0.074884	min_logloss=0.074197
# [29/50]	eval_time=1633.80 sec	current_logloss=0.075297	min_logloss=0.074197
# [30/50]	eval_time=738.40 sec	current_logloss=0.076152	min_logloss=0.074197
# [31/50]	eval_time=2821.87 sec	current_logloss=0.077835	min_logloss=0.074197
# [32/50]	eval_time=675.44 sec	current_logloss=0.074536	min_logloss=0.074197
# [33/50]	eval_time=1506.78 sec	current_logloss=0.074355	min_logloss=0.074197
# [34/50]	eval_time=829.19 sec	current_logloss=0.082974	min_logloss=0.074197
# [35/50]	eval_time=2482.63 sec	current_logloss=0.075237	min_logloss=0.074197
# [36/50]	eval_time=1623.60 sec	current_logloss=0.076916	min_logloss=0.074197
# [37/50]	eval_time=1241.06 sec	current_logloss=0.074168	min_logloss=0.074168
# [38/50]	eval_time=1912.63 sec	current_logloss=0.074448	min_logloss=0.074168
# [39/50]	eval_time=1197.06 sec	current_logloss=0.074140	min_logloss=0.074140
# [40/50]	eval_time=2098.45 sec	current_logloss=0.075514	min_logloss=0.074140
# [41/50]	eval_time=1165.33 sec	current_logloss=0.074147	min_logloss=0.074140
# [42/50]	eval_time=797.26 sec	current_logloss=0.074392	min_logloss=0.074140
# [43/50]	eval_time=967.97 sec	current_logloss=0.075243	min_logloss=0.074140
# [44/50]	eval_time=1593.37 sec	current_logloss=0.074377	min_logloss=0.074140
# [45/50]	eval_time=1893.64 sec	current_logloss=0.074694	min_logloss=0.074140
# [46/50]	eval_time=1832.72 sec	current_logloss=0.075126	min_logloss=0.074140
# [47/50]	eval_time=741.62 sec	current_logloss=0.074783	min_logloss=0.074140
# [48/50]	eval_time=749.42 sec	current_logloss=0.075152	min_logloss=0.074140
# [49/50]	eval_time=1995.44 sec	current_logloss=0.074949	min_logloss=0.074140
# [50/50]	eval_time=1150.50 sec	current_logloss=0.074539	min_logloss=0.074140
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned XGBoost result on cv:
#
# logloss = 0.0741404
# best_n_estimators = 1240
# params = {'colsample_bytree': 0.7480722535031745, 'silent': 1, 'eval_metric': 'logloss', 'colsample_bylevel': 0.9985145442490182, 'min_child_weight': 12.516613094498105, 'subsample': 0.8458301286552772, 'eta': 0.007269176273103756, 'objective': 'binary:logistic', 'alpha': 9.747950214636593e-05, 'seed': 0, 'max_depth': 3, 'gamma': 0, 'lambda': 0}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned XGBoost result on test:
#
# For seed=0 Test's logloss : 0.071781
# For seed=1 Test's logloss : 0.071760
# For seed=2 Test's logloss : 0.071733
# For seed=3 Test's logloss : 0.071755
# For seed=4 Test's logloss : 0.071772
#
# Test's logloss mean: 0.071760, Test's logloss std: 0.000016

# %% [markdown]
# ## `LightGBM`

# %%
lgb_default_test_result, lgb_tuned_test_result = run_experiment(LGBExperiment, "LightGBM")
# Out:
# Default LightGBM result on cv:
#
# logloss = 0.077085489256
# best_n_estimators = 58
# params = {'feature_fraction_seed': 0, 'num_leaves': 127, 'verbose': -1, 'bagging_seed': 0, 'lambda_l1': 0, 'drop_seed': 0, 'learning_rate': 0.1, 'lambda_l2': 0, 'data_random_seed': 0, 'bagging_fraction': 1.0, 'min_data_in_leaf': 100, 'max_bin': 255, 'objective': 'binary', 'bagging_freq': 1, 'metric': 'binary_logloss', 'min_sum_hessian_in_leaf': 10, 'feature_fraction': 1.0}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Default LightGBM result on test:
#
# For seed=0 Test's logloss : 0.074823
# For seed=1 Test's logloss : 0.074823
# For seed=2 Test's logloss : 0.074823
# For seed=3 Test's logloss : 0.074823
# For seed=4 Test's logloss : 0.074823
#
# Test's logloss mean: 0.074823, Test's logloss std: 0.000000
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Hyperopt iterations:
#
# [1/50]	eval_time=126.34 sec	current_logloss=0.075995	min_logloss=0.075995
# [2/50]	eval_time=85.66 sec	current_logloss=0.074892	min_logloss=0.074892
# [3/50]	eval_time=296.44 sec	current_logloss=0.075251	min_logloss=0.074892
# [4/50]	eval_time=63.85 sec	current_logloss=0.076118	min_logloss=0.074892
# [5/50]	eval_time=123.11 sec	current_logloss=0.083480	min_logloss=0.074892
# [6/50]	eval_time=1040.78 sec	current_logloss=0.080792	min_logloss=0.074892
# [7/50]	eval_time=263.77 sec	current_logloss=0.075189	min_logloss=0.074892
# [8/50]	eval_time=76.41 sec	current_logloss=0.074744	min_logloss=0.074744
# [9/50]	eval_time=103.82 sec	current_logloss=0.075201	min_logloss=0.074744
# [10/50]	eval_time=154.40 sec	current_logloss=0.078706	min_logloss=0.074744
# [11/50]	eval_time=182.71 sec	current_logloss=0.074525	min_logloss=0.074525
# [12/50]	eval_time=140.32 sec	current_logloss=0.083208	min_logloss=0.074525
# [13/50]	eval_time=149.04 sec	current_logloss=0.096202	min_logloss=0.074525
# [14/50]	eval_time=100.67 sec	current_logloss=0.074724	min_logloss=0.074525
# [15/50]	eval_time=86.75 sec	current_logloss=0.077512	min_logloss=0.074525
# [16/50]	eval_time=81.10 sec	current_logloss=0.106561	min_logloss=0.074525
# [17/50]	eval_time=79.98 sec	current_logloss=0.080186	min_logloss=0.074525
# [18/50]	eval_time=828.12 sec	current_logloss=0.077490	min_logloss=0.074525
# [19/50]	eval_time=465.42 sec	current_logloss=0.084579	min_logloss=0.074525
# [20/50]	eval_time=147.54 sec	current_logloss=0.081112	min_logloss=0.074525
# [21/50]	eval_time=112.96 sec	current_logloss=0.074250	min_logloss=0.074250
# [22/50]	eval_time=134.12 sec	current_logloss=0.074273	min_logloss=0.074250
# [23/50]	eval_time=118.68 sec	current_logloss=0.074123	min_logloss=0.074123
# [24/50]	eval_time=112.67 sec	current_logloss=0.074138	min_logloss=0.074123
# [25/50]	eval_time=103.87 sec	current_logloss=0.074057	min_logloss=0.074057
# [26/50]	eval_time=71.22 sec	current_logloss=0.074762	min_logloss=0.074057
# [27/50]	eval_time=112.22 sec	current_logloss=0.074222	min_logloss=0.074057
# [28/50]	eval_time=233.94 sec	current_logloss=0.074637	min_logloss=0.074057
# [29/50]	eval_time=78.85 sec	current_logloss=0.074933	min_logloss=0.074057
# [30/50]	eval_time=234.03 sec	current_logloss=0.075085	min_logloss=0.074057
# [31/50]	eval_time=112.93 sec	current_logloss=0.074151	min_logloss=0.074057
# [32/50]	eval_time=102.89 sec	current_logloss=0.074128	min_logloss=0.074057
# [33/50]	eval_time=76.52 sec	current_logloss=0.080653	min_logloss=0.074057
# [34/50]	eval_time=217.85 sec	current_logloss=0.075970	min_logloss=0.074057
# [35/50]	eval_time=128.77 sec	current_logloss=0.074520	min_logloss=0.074057
# [36/50]	eval_time=109.16 sec	current_logloss=0.074794	min_logloss=0.074057
# [37/50]	eval_time=89.71 sec	current_logloss=0.075452	min_logloss=0.074057
# [38/50]	eval_time=268.96 sec	current_logloss=0.075447	min_logloss=0.074057
# [39/50]	eval_time=223.54 sec	current_logloss=0.074828	min_logloss=0.074057
# [40/50]	eval_time=118.70 sec	current_logloss=0.074453	min_logloss=0.074057
# [41/50]	eval_time=163.62 sec	current_logloss=0.074342	min_logloss=0.074057
# [42/50]	eval_time=141.66 sec	current_logloss=0.074590	min_logloss=0.074057
# [43/50]	eval_time=96.10 sec	current_logloss=0.074509	min_logloss=0.074057
# [44/50]	eval_time=449.97 sec	current_logloss=0.076939	min_logloss=0.074057
# [45/50]	eval_time=110.54 sec	current_logloss=0.080495	min_logloss=0.074057
# [46/50]	eval_time=225.28 sec	current_logloss=0.075217	min_logloss=0.074057
# [47/50]	eval_time=210.28 sec	current_logloss=0.080464	min_logloss=0.074057
# [48/50]	eval_time=172.41 sec	current_logloss=0.074818	min_logloss=0.074057
# [49/50]	eval_time=104.88 sec	current_logloss=0.074848	min_logloss=0.074057
# [50/50]	eval_time=108.20 sec	current_logloss=0.074822	min_logloss=0.074057
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned LightGBM result on cv:
#
# logloss = 0.0740572099502
# best_n_estimators = 924
# params = {'num_leaves': 6, 'verbose': -1, 'bagging_seed': 0, 'metric': 'binary_logloss', 'data_random_seed': 0, 'min_data_in_leaf': 95, 'bagging_fraction': 0.8956806282244631, 'min_sum_hessian_in_leaf': 0.05112201732261002, 'feature_fraction_seed': 0, 'lambda_l1': 0.013807846588423104, 'bagging_freq': 1, 'lambda_l2': 0, 'objective': 'binary', 'drop_seed': 0, 'learning_rate': 0.012538826956019477, 'feature_fraction': 0.5112693049121645}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned LightGBM result on test:
#
# For seed=0 Test's logloss : 0.071679
# For seed=1 Test's logloss : 0.071696
# For seed=2 Test's logloss : 0.071862
# For seed=3 Test's logloss : 0.071785
# For seed=4 Test's logloss : 0.071955
#
# Test's logloss mean: 0.071795, Test's logloss std: 0.000103

# %% [markdown]
# ## `CatBoost`

# %%
cab_default_test_result, cab_tuned_test_result = run_experiment(CABExperiment, "CatBoost")
# Out:
# Default CatBoost result on cv:
#
# logloss = 0.07342469412
# best_n_estimators = 709
# params = {'rsm': 1.0, 'iterations': 709, 'random_seed': 4, 'verbose': False, 'thread_count': 16, 'learning_rate': 0.03, 'ctr_description': ['Borders', 'CounterMax'], 'depth': 6, 'fold_len_multiplier': 2, 'loss_function': 'Logloss', 'ctr_border_count': 16, 'l2_leaf_reg': 3, 'leaf_estimation_method': 'Newton', 'gradient_iterations': 10, 'border_count': 128, 'used_ram_limit': 100000000000}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Default CatBoost result on test:
#
# For seed=0 Test's logloss : 0.071651
# For seed=1 Test's logloss : 0.071279
# For seed=2 Test's logloss : 0.071100
# For seed=3 Test's logloss : 0.071703
# For seed=4 Test's logloss : 0.071176
#
# Test's logloss mean: 0.071382, Test's logloss std: 0.000248
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Hyperopt iterations:
#
# [1/50]	eval_time=2071.47 sec	current_logloss=0.073602	min_logloss=0.073602
# [2/50]	eval_time=3167.58 sec	current_logloss=0.073882	min_logloss=0.073602
# [3/50]	eval_time=1998.21 sec	current_logloss=0.073816	min_logloss=0.073602
# [4/50]	eval_time=2034.43 sec	current_logloss=0.073584	min_logloss=0.073584
# [5/50]	eval_time=3044.21 sec	current_logloss=0.073290	min_logloss=0.073290
# [6/50]	eval_time=2062.07 sec	current_logloss=0.073597	min_logloss=0.073290
# [7/50]	eval_time=2058.98 sec	current_logloss=0.073685	min_logloss=0.073290
# [8/50]	eval_time=2258.10 sec	current_logloss=0.073805	min_logloss=0.073290
# [9/50]	eval_time=3192.55 sec	current_logloss=0.075507	min_logloss=0.073290
# [10/50]	eval_time=3326.50 sec	current_logloss=0.073532	min_logloss=0.073290
# [11/50]	eval_time=3003.10 sec	current_logloss=0.073359	min_logloss=0.073290
# [12/50]	eval_time=3165.36 sec	current_logloss=0.073458	min_logloss=0.073290
# [13/50]	eval_time=2047.19 sec	current_logloss=0.073640	min_logloss=0.073290
# [14/50]	eval_time=2210.98 sec	current_logloss=0.073598	min_logloss=0.073290
# [15/50]	eval_time=3162.76 sec	current_logloss=0.073219	min_logloss=0.073219
# [16/50]	eval_time=2299.91 sec	current_logloss=0.074620	min_logloss=0.073219
# [17/50]	eval_time=3410.26 sec	current_logloss=0.074086	min_logloss=0.073219
# [18/50]	eval_time=3088.75 sec	current_logloss=0.073417	min_logloss=0.073219
# [19/50]	eval_time=2081.51 sec	current_logloss=0.073591	min_logloss=0.073219
# [20/50]	eval_time=2276.14 sec	current_logloss=0.073806	min_logloss=0.073219
# [21/50]	eval_time=3281.81 sec	current_logloss=0.073220	min_logloss=0.073219
# [22/50]	eval_time=3282.29 sec	current_logloss=0.073203	min_logloss=0.073203
# [23/50]	eval_time=3310.28 sec	current_logloss=0.073253	min_logloss=0.073203
# [24/50]	eval_time=3253.53 sec	current_logloss=0.073206	min_logloss=0.073203
# [25/50]	eval_time=3269.35 sec	current_logloss=0.073212	min_logloss=0.073203
# [26/50]	eval_time=3285.93 sec	current_logloss=0.073230	min_logloss=0.073203
# [27/50]	eval_time=3411.85 sec	current_logloss=0.076453	min_logloss=0.073203
# [28/50]	eval_time=3346.96 sec	current_logloss=0.073614	min_logloss=0.073203
# [29/50]	eval_time=3326.31 sec	current_logloss=0.073343	min_logloss=0.073203
# [30/50]	eval_time=3236.46 sec	current_logloss=0.073227	min_logloss=0.073203
# [31/50]	eval_time=3419.81 sec	current_logloss=0.074070	min_logloss=0.073203
# [32/50]	eval_time=3307.58 sec	current_logloss=0.073196	min_logloss=0.073196
# [33/50]	eval_time=3302.58 sec	current_logloss=0.073294	min_logloss=0.073196
# [34/50]	eval_time=3354.14 sec	current_logloss=0.073319	min_logloss=0.073196
# [35/50]	eval_time=3345.26 sec	current_logloss=0.073402	min_logloss=0.073196
# [36/50]	eval_time=3231.78 sec	current_logloss=0.073206	min_logloss=0.073196
# [37/50]	eval_time=3318.55 sec	current_logloss=0.073131	min_logloss=0.073131
# [38/50]	eval_time=3354.21 sec	current_logloss=0.073595	min_logloss=0.073131
# [39/50]	eval_time=3321.20 sec	current_logloss=0.073082	min_logloss=0.073082
# [40/50]	eval_time=2260.47 sec	current_logloss=0.073476	min_logloss=0.073082
# [41/50]	eval_time=3374.59 sec	current_logloss=0.073340	min_logloss=0.073082
# [42/50]	eval_time=3320.07 sec	current_logloss=0.073535	min_logloss=0.073082
# [43/50]	eval_time=2098.55 sec	current_logloss=0.073509	min_logloss=0.073082
# [44/50]	eval_time=3329.60 sec	current_logloss=0.073449	min_logloss=0.073082
# [45/50]	eval_time=3186.24 sec	current_logloss=0.073345	min_logloss=0.073082
# [46/50]	eval_time=2214.85 sec	current_logloss=0.073709	min_logloss=0.073082
# [47/50]	eval_time=3193.85 sec	current_logloss=0.073518	min_logloss=0.073082
# [48/50]	eval_time=3442.48 sec	current_logloss=0.074708	min_logloss=0.073082
# [49/50]	eval_time=2272.60 sec	current_logloss=0.073713	min_logloss=0.073082
# [50/50]	eval_time=3199.61 sec	current_logloss=0.073314	min_logloss=0.073082
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned CatBoost result on cv:
#
# logloss = 0.073081792948
# best_n_estimators = 679
# params = {'random_seed': 4, 'verbose': False, 'thread_count': 16, 'learning_rate': 0.028314923653565784, 'ctr_border_count': 16, 'ctr_description': ('Borders', 'CounterMax'), 'iterations': 679, 'one_hot_max_size': 0, 'bagging_temperature': 0.62965733300935, 'gradient_iterations': 10, 'random_strength': 1, 'depth': 6, 'loss_function': 'Logloss', 'l2_leaf_reg': 7.938314685786722, 'border_count': 128, 'used_ram_limit': 100000000000}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Tuned CatBoost result on test:
#
# For seed=0 Test's logloss : 0.071734
# For seed=1 Test's logloss : 0.071514
# For seed=2 Test's logloss : 0.071541
# For seed=3 Test's logloss : 0.071450
# For seed=4 Test's logloss : 0.071319
#
# Test's logloss mean: 0.071511, Test's logloss std: 0.000135

# %% [markdown]
# ## Comparing results
#
# The final table with metric values on the test dataset.

# %%
import pandas as pd
import numpy as np
from IPython.display import HTML, display
# %pylab inline --no-import-all

test_results = np.array([
    (xgb_default_test_result, xgb_tuned_test_result),
    (lgb_default_test_result, lgb_tuned_test_result),
    (cab_default_test_result, cab_tuned_test_result)
])

diff = 100 * test_results / test_results[2,1] - 100

res = [['{:.6f} ({:+.2f}%)'.format(test_results[i, j], diff[i, j]) for j in range(2)] for i in range(3)]

display(HTML(pd.DataFrame(res, columns=['default', 'tuned'], index=['xgboost', 'lightgbm', 'catboost']).to_html()))

results = [
    ('Tuned CatBoost',   cab_tuned_test_result),
    ('Default CatBoost', cab_default_test_result),
    ('Tuned XGBoost',    xgb_tuned_test_result),
    ('Default XGBoost',  xgb_default_test_result),
    ('Tuned LightGBM',   lgb_tuned_test_result),
    ('Default LightGBM', lgb_default_test_result),
]
names = ['%s\n%.5f' % (name, loss) for name, loss in results]

plt.figure(figsize=(20, 7))
plt.scatter(range(6), zip(*results)[1], s=150)
plt.xticks(range(6), names, fontsize=15)
plt.yticks(fontsize=12)
plt.title('Comparison', fontsize=20)
plt.ylabel(experiment.metric, fontsize=16);
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>default</th>
#       <th>tuned</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>xgboost</th>
#       <td>0.074659 (+4.40%)</td>
#       <td>0.071760 (+0.35%)</td>
#     </tr>
#     <tr>
#       <th>lightgbm</th>
#       <td>0.074823 (+4.63%)</td>
#       <td>0.071795 (+0.40%)</td>
#     </tr>
#     <tr>
#       <th>catboost</th>
#       <td>0.071382 (-0.18%)</td>
#       <td>0.071511 (+0.00%)</td>
#     </tr>
#   </tbody>
# </table>
